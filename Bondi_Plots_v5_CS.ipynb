# %% [markdown]
# # Frontiers, Bondi Eqs. with consistency

# %%
import yt
from yt.units import kpc
import numpy as np
import yt.visualization.eps_writer as eps
import matplotlib.pyplot as plt
from yt import derived_field
from matplotlib import pylab
from yt.mods import * # set up our namespace
from mpl_toolkits.axes_grid1 import AxesGrid
from os.path import exists

fig = plt.figure()
########################################

#### -----
def putStyle(sFont,syT,top1,R1):
    import matplotlib as mpl
    import matplotlib.style as style
    style.available

    # General plot parameters
    mpl.rcParams['font.family'] = 'Avenir'
    mpl.rcParams['font.size'] = sFont
    mpl.rcParams['axes.linewidth'] = 4
    mpl.rcParams['axes.spines.bottom'] = top1
    mpl.rcParams['axes.spines.right'] = R1
    mpl.rcParams['xtick.major.size'] = 10
    mpl.rcParams['xtick.major.width'] = 2
    mpl.rcParams['ytick.major.size'] = 10
    mpl.rcParams['ytick.major.width'] = syT
    mpl.rcParams['lines.linewidth']= 3
    mpl.rcParams["figure.figsize"] = (8,8)

# %%
## 10pc
Rad0=3.08568e+19
Vel00=6.55844e+06
Vel0=6.55844e+06 #


unit_base = {'UnitLength_in_cm'         :   Rad0,
             'UnitMass_in_g'            :   1.98892e+40,
             'UnitVelocity_in_cm_per_s' :   Vel0,
             'GravityConstantInternal'  :   0,
             }

bbox_lim = 20.0 #codelength

bbox = [[-bbox_lim,bbox_lim],
        [-bbox_lim,bbox_lim],
        [-bbox_lim,bbox_lim]]

# %%
### --
### Directorio de la simulacion!!!--- ###############################################
sim_dir1="./all_aciis_0/"
sim_dir2="./all_aciis_1/"
sim_dir3="./all_aciis_2/"
sim_dir4="./all_aciis_3/"

sim_Gen=[sim_dir1, sim_dir2, sim_dir3, sim_dir4]
#####################################################################################

### Finalmente levanto la data!!--
#######################################

ds_Gall=[]

## 2 loops--
for k in sim_Gen:
### G11 Particles!!--
    for i in range(0,1001):
        if i<10: fn = k+"snapshot_000%i" % i
        if i >10 and i<100: fn = k+"snapshot_00%i" % i
        if i>100 and i<1000: fn = k+"snapshot_0%i" % i
            
        if exists(fn):
            dt = yt.load(fn,
                unit_base=unit_base,  ## -- No voy a override the units. Take them from the file
                bounding_box=bbox)
            ###
            ds_Gall.append(dt)
            print(dt)
    #######################################
    #######################################
# Out:
# yt : [INFO     ] 2022-02-15 12:21:29,062 Omega Lambda is 0.0, so we are turning off Cosmology.
# yt : [INFO     ] 2022-02-15 12:21:29,147 Parameters: current_time              = 0.0
# yt : [INFO     ] 2022-02-15 12:21:29,148 Parameters: domain_dimensions         = [1 1 1]
# yt : [INFO     ] 2022-02-15 12:21:29,149 Parameters: domain_left_edge          = [-20. -20. -20.]
# yt : [INFO     ] 2022-02-15 12:21:29,150 Parameters: domain_right_edge         = [20. 20. 20.]
# yt : [INFO     ] 2022-02-15 12:21:29,150 Parameters: cosmological_simulation   = 0
# yt : [INFO     ] 2022-02-15 12:21:29,163 Omega Lambda is 0.0, so we are turning off Cosmology.
# yt : [INFO     ] 2022-02-15 12:21:29,243 Parameters: current_time              = 0.05
# yt : [INFO     ] 2022-02-15 12:21:29,243 Parameters: domain_dimensions         = [1 1 1]
# yt : [INFO     ] 2022-02-15 12:21:29,244 Parameters: domain_left_edge          = [-20. -20. -20.]
# yt : [INFO     ] 2022-02-15 12:21:29,245 Parameters: domain_right_edge         = [20. 20. 20.]
# yt : [INFO     ] 2022-02-15 12:21:29,246 Parameters: cosmological_simulation   = 0
# yt : [INFO     ] 2022-02-15 12:21:29,258 Omega Lambda is 0.0, so we are turning off Cosmology.
# yt : [INFO     ] 2022-02-15 12:21:29,336 Parameters: current_time              = 0.1
# yt : [INFO     ] 2022-02-15 12:21:29,337 Parameters: domain_dimensions         = [1 1 1]
# yt : [INFO     ] 2022-02-15 12:21:29,337 Parameters: domain_left_edge          = [-20. -20. -20.]
# yt : [INFO     ] 2022-02-15 12:21:29,338 Parameters: domain_right_edge         = [20. 20. 20.]
# yt : [INFO     ] 2022-02-15 12:21:29,339 Parameters: cosmological_simulation   = 0
# yt : [INFO     ] 2022-02-15 12:21:29,349 Omega Lambda is 0.0, so we are turning off Cosmology.
# snapshot_0000
# snapshot_0001
# snapshot_0002
# yt : [INFO     ] 2022-02-15 12:21:29,414 Parameters: current_time              = 0.15000000000000002
# yt : [INFO     ] 2022-02-15 12:21:29,415 Parameters: domain_dimensions         = [1 1 1]
# yt : [INFO     ] 2022-02-15 12:21:29,416 Parameters: domain_left_edge          = [-20. -20. -20.]
# yt : [INFO     ] 2022-02-15 12:21:29,417 Parameters: domain_right_edge         = [20. 20. 20.]
# yt : [INFO     ] 2022-02-15 12:21:29,418 Parameters: cosmological_simulation   = 0
# yt : [INFO     ] 2022-02-15 12:21:29,429 Omega Lambda is 0.0, so we are turning off Cosmology.
# yt : [INFO     ] 2022-02-15 12:21:29,492 Parameters: current_time              = 0.2
# yt : [INFO     ] 2022-02-15 12:21:29,493 Parameters: domain_dimensions         = [1 1 1]
# yt : [INFO     ] 2022-02-15 12:21:29,494 Parameters: domain_left_edge          = [-20. -20. -20.]
# yt : [INFO     ] 2022-02-15 12:21:29,494 Parameters: domain_right_edge         = [20. 20. 20.]
# yt : [INFO     ] 2022-02-15 12:21:29,495 Parameters: cosmological_simulation   = 0
# yt : [INFO     ] 2022-02-15 12:21:29,506 Omega Lambda is 0.0, so we are turning off Cosmology.
# yt : [INFO     ] 2022-02-15 12:21:29,569 Parameters: current_time              = 0.2
# yt : [INFO     ] 2022-02-15 12:21:29,570 Parameters: domain_dimensions         = [1 1 1]
# yt : [INFO     ] 2022-02-15 12:21:29,571 Parameters: domain_left_edge          = [-20. -20. -20.]
# yt : [INFO     ] 2022-02-15 12:21:29,572 Parameters: domain_right_edge         = [20. 20. 20.]
# yt : [INFO     ] 2022-02-15 12:21:29,573 Parameters: cosmological_simulation   = 0
# yt : [INFO     ] 2022-02-15 12:21:29,594 Omega Lambda is 0.0, so we are turning off Cosmology.
# snapshot_0003
# snapshot_0004
# snapshot_0005
# yt : [INFO     ] 2022-02-15 12:21:29,657 Parameters: current_time              = 0.0
# yt : [INFO     ] 2022-02-15 12:21:29,658 Parameters: domain_dimensions         = [1 1 1]
# yt : [INFO     ] 2022-02-15 12:21:29,659 Parameters: domain_left_edge          = [-20. -20. -20.]
# yt : [INFO     ] 2022-02-15 12:21:29,660 Parameters: domain_right_edge         = [20. 20. 20.]
# yt : [INFO     ] 2022-02-15 12:21:29,661 Parameters: cosmological_simulation   = 0
# yt : [INFO     ] 2022-02-15 12:21:29,671 Omega Lambda is 0.0, so we are turning off Cosmology.
# yt : [INFO     ] 2022-02-15 12:21:29,733 Parameters: current_time              = 0.05
# yt : [INFO     ] 2022-02-15 12:21:29,734 Parameters: domain_dimensions         = [1 1 1]
# yt : [INFO     ] 2022-02-15 12:21:29,735 Parameters: domain_left_edge          = [-20. -20. -20.]
# yt : [INFO     ] 2022-02-15 12:21:29,736 Parameters: domain_right_edge         = [20. 20. 20.]
# yt : [INFO     ] 2022-02-15 12:21:29,737 Parameters: cosmological_simulation   = 0
# yt : [INFO     ] 2022-02-15 12:21:29,749 Omega Lambda is 0.0, so we are turning off Cosmology.
# yt : [INFO     ] 2022-02-15 12:21:29,812 Parameters: current_time              = 0.1
# yt : [INFO     ] 2022-02-15 12:21:29,813 Parameters: domain_dimensions         = [1 1 1]
# yt : [INFO     ] 2022-02-15 12:21:29,813 Parameters: domain_left_edge          = [-20. -20. -20.]
# yt : [INFO     ] 2022-02-15 12:21:29,814 Parameters: domain_right_edge         = [20. 20. 20.]
# yt : [INFO     ] 2022-02-15 12:21:29,815 Parameters: cosmological_simulation   = 0
# yt : [INFO     ] 2022-02-15 12:21:29,825 Omega Lambda is 0.0, so we are turning off Cosmology.
# snapshot_0000
# snapshot_0001
# snapshot_0002
# yt : [INFO     ] 2022-02-15 12:21:29,889 Parameters: current_time              = 0.15000000000000002
# yt : [INFO     ] 2022-02-15 12:21:29,890 Parameters: domain_dimensions         = [1 1 1]
# yt : [INFO     ] 2022-02-15 12:21:29,891 Parameters: domain_left_edge          = [-20. -20. -20.]
# yt : [INFO     ] 2022-02-15 12:21:29,892 Parameters: domain_right_edge         = [20. 20. 20.]
# yt : [INFO     ] 2022-02-15 12:21:29,893 Parameters: cosmological_simulation   = 0
# yt : [INFO     ] 2022-02-15 12:21:29,905 Omega Lambda is 0.0, so we are turning off Cosmology.
# yt : [INFO     ] 2022-02-15 12:21:29,971 Parameters: current_time              = 0.2
# yt : [INFO     ] 2022-02-15 12:21:29,971 Parameters: domain_dimensions         = [1 1 1]
# yt : [INFO     ] 2022-02-15 12:21:29,972 Parameters: domain_left_edge          = [-20. -20. -20.]
# yt : [INFO     ] 2022-02-15 12:21:29,973 Parameters: domain_right_edge         = [20. 20. 20.]
# yt : [INFO     ] 2022-02-15 12:21:29,974 Parameters: cosmological_simulation   = 0
# yt : [INFO     ] 2022-02-15 12:21:29,985 Omega Lambda is 0.0, so we are turning off Cosmology.
# yt : [INFO     ] 2022-02-15 12:21:30,049 Parameters: current_time              = 0.2
# yt : [INFO     ] 2022-02-15 12:21:30,049 Parameters: domain_dimensions         = [1 1 1]
# yt : [INFO     ] 2022-02-15 12:21:30,050 Parameters: domain_left_edge          = [-20. -20. -20.]
# yt : [INFO     ] 2022-02-15 12:21:30,051 Parameters: domain_right_edge         = [20. 20. 20.]
# yt : [INFO     ] 2022-02-15 12:21:30,052 Parameters: cosmological_simulation   = 0
# yt : [INFO     ] 2022-02-15 12:21:30,071 Omega Lambda is 0.0, so we are turning off Cosmology.
# snapshot_0003
# snapshot_0004
# snapshot_0005
# yt : [INFO     ] 2022-02-15 12:21:30,133 Parameters: current_time              = 0.0
# yt : [INFO     ] 2022-02-15 12:21:30,134 Parameters: domain_dimensions         = [1 1 1]
# yt : [INFO     ] 2022-02-15 12:21:30,135 Parameters: domain_left_edge          = [-20. -20. -20.]
# yt : [INFO     ] 2022-02-15 12:21:30,136 Parameters: domain_right_edge         = [20. 20. 20.]
# yt : [INFO     ] 2022-02-15 12:21:30,137 Parameters: cosmological_simulation   = 0
# yt : [INFO     ] 2022-02-15 12:21:30,147 Omega Lambda is 0.0, so we are turning off Cosmology.
# yt : [INFO     ] 2022-02-15 12:21:30,210 Parameters: current_time              = 0.05
# yt : [INFO     ] 2022-02-15 12:21:30,211 Parameters: domain_dimensions         = [1 1 1]
# yt : [INFO     ] 2022-02-15 12:21:30,212 Parameters: domain_left_edge          = [-20. -20. -20.]
# yt : [INFO     ] 2022-02-15 12:21:30,212 Parameters: domain_right_edge         = [20. 20. 20.]
# yt : [INFO     ] 2022-02-15 12:21:30,213 Parameters: cosmological_simulation   = 0
# yt : [INFO     ] 2022-02-15 12:21:30,224 Omega Lambda is 0.0, so we are turning off Cosmology.
# yt : [INFO     ] 2022-02-15 12:21:30,288 Parameters: current_time              = 0.1
# yt : [INFO     ] 2022-02-15 12:21:30,288 Parameters: domain_dimensions         = [1 1 1]
# yt : [INFO     ] 2022-02-15 12:21:30,289 Parameters: domain_left_edge          = [-20. -20. -20.]
# yt : [INFO     ] 2022-02-15 12:21:30,290 Parameters: domain_right_edge         = [20. 20. 20.]
# yt : [INFO     ] 2022-02-15 12:21:30,291 Parameters: cosmological_simulation   = 0
# yt : [INFO     ] 2022-02-15 12:21:30,303 Omega Lambda is 0.0, so we are turning off Cosmology.
# snapshot_0000
# snapshot_0001
# snapshot_0002
# yt : [INFO     ] 2022-02-15 12:21:30,367 Parameters: current_time              = 0.15000000000000002
# yt : [INFO     ] 2022-02-15 12:21:30,368 Parameters: domain_dimensions         = [1 1 1]
# yt : [INFO     ] 2022-02-15 12:21:30,368 Parameters: domain_left_edge          = [-20. -20. -20.]
# yt : [INFO     ] 2022-02-15 12:21:30,369 Parameters: domain_right_edge         = [20. 20. 20.]
# yt : [INFO     ] 2022-02-15 12:21:30,370 Parameters: cosmological_simulation   = 0
# yt : [INFO     ] 2022-02-15 12:21:30,381 Omega Lambda is 0.0, so we are turning off Cosmology.
# yt : [INFO     ] 2022-02-15 12:21:30,444 Parameters: current_time              = 0.2
# yt : [INFO     ] 2022-02-15 12:21:30,445 Parameters: domain_dimensions         = [1 1 1]
# yt : [INFO     ] 2022-02-15 12:21:30,446 Parameters: domain_left_edge          = [-20. -20. -20.]
# yt : [INFO     ] 2022-02-15 12:21:30,447 Parameters: domain_right_edge         = [20. 20. 20.]
# yt : [INFO     ] 2022-02-15 12:21:30,448 Parameters: cosmological_simulation   = 0
# yt : [INFO     ] 2022-02-15 12:21:30,460 Omega Lambda is 0.0, so we are turning off Cosmology.
# yt : [INFO     ] 2022-02-15 12:21:30,522 Parameters: current_time              = 0.2
# yt : [INFO     ] 2022-02-15 12:21:30,523 Parameters: domain_dimensions         = [1 1 1]
# yt : [INFO     ] 2022-02-15 12:21:30,524 Parameters: domain_left_edge          = [-20. -20. -20.]
# yt : [INFO     ] 2022-02-15 12:21:30,525 Parameters: domain_right_edge         = [20. 20. 20.]
# yt : [INFO     ] 2022-02-15 12:21:30,526 Parameters: cosmological_simulation   = 0
# yt : [INFO     ] 2022-02-15 12:21:30,544 Omega Lambda is 0.0, so we are turning off Cosmology.
# yt : [INFO     ] 2022-02-15 12:21:30,602 Parameters: current_time              = 0.0
# snapshot_0003
# snapshot_0004
# snapshot_0005
# yt : [INFO     ] 2022-02-15 12:21:30,603 Parameters: domain_dimensions         = [1 1 1]
# yt : [INFO     ] 2022-02-15 12:21:30,604 Parameters: domain_left_edge          = [-20. -20. -20.]
# yt : [INFO     ] 2022-02-15 12:21:30,605 Parameters: domain_right_edge         = [20. 20. 20.]
# yt : [INFO     ] 2022-02-15 12:21:30,606 Parameters: cosmological_simulation   = 0
# yt : [INFO     ] 2022-02-15 12:21:30,616 Omega Lambda is 0.0, so we are turning off Cosmology.
# yt : [INFO     ] 2022-02-15 12:21:30,677 Parameters: current_time              = 0.05
# yt : [INFO     ] 2022-02-15 12:21:30,678 Parameters: domain_dimensions         = [1 1 1]
# yt : [INFO     ] 2022-02-15 12:21:30,679 Parameters: domain_left_edge          = [-20. -20. -20.]
# yt : [INFO     ] 2022-02-15 12:21:30,680 Parameters: domain_right_edge         = [20. 20. 20.]
# yt : [INFO     ] 2022-02-15 12:21:30,681 Parameters: cosmological_simulation   = 0
# yt : [INFO     ] 2022-02-15 12:21:30,691 Omega Lambda is 0.0, so we are turning off Cosmology.
# yt : [INFO     ] 2022-02-15 12:21:30,756 Parameters: current_time              = 0.1
# yt : [INFO     ] 2022-02-15 12:21:30,757 Parameters: domain_dimensions         = [1 1 1]
# yt : [INFO     ] 2022-02-15 12:21:30,757 Parameters: domain_left_edge          = [-20. -20. -20.]
# yt : [INFO     ] 2022-02-15 12:21:30,758 Parameters: domain_right_edge         = [20. 20. 20.]
# yt : [INFO     ] 2022-02-15 12:21:30,759 Parameters: cosmological_simulation   = 0
# yt : [INFO     ] 2022-02-15 12:21:30,769 Omega Lambda is 0.0, so we are turning off Cosmology.
# snapshot_0000
# snapshot_0001
# snapshot_0002
# yt : [INFO     ] 2022-02-15 12:21:30,832 Parameters: current_time              = 0.15000000000000002
# yt : [INFO     ] 2022-02-15 12:21:30,833 Parameters: domain_dimensions         = [1 1 1]
# yt : [INFO     ] 2022-02-15 12:21:30,834 Parameters: domain_left_edge          = [-20. -20. -20.]
# yt : [INFO     ] 2022-02-15 12:21:30,835 Parameters: domain_right_edge         = [20. 20. 20.]
# yt : [INFO     ] 2022-02-15 12:21:30,836 Parameters: cosmological_simulation   = 0
# yt : [INFO     ] 2022-02-15 12:21:30,847 Omega Lambda is 0.0, so we are turning off Cosmology.
# yt : [INFO     ] 2022-02-15 12:21:30,910 Parameters: current_time              = 0.2
# yt : [INFO     ] 2022-02-15 12:21:30,910 Parameters: domain_dimensions         = [1 1 1]
# yt : [INFO     ] 2022-02-15 12:21:30,911 Parameters: domain_left_edge          = [-20. -20. -20.]
# yt : [INFO     ] 2022-02-15 12:21:30,912 Parameters: domain_right_edge         = [20. 20. 20.]
# yt : [INFO     ] 2022-02-15 12:21:30,913 Parameters: cosmological_simulation   = 0
# yt : [INFO     ] 2022-02-15 12:21:30,923 Omega Lambda is 0.0, so we are turning off Cosmology.
# yt : [INFO     ] 2022-02-15 12:21:30,983 Parameters: current_time              = 0.2
# yt : [INFO     ] 2022-02-15 12:21:30,984 Parameters: domain_dimensions         = [1 1 1]
# yt : [INFO     ] 2022-02-15 12:21:30,985 Parameters: domain_left_edge          = [-20. -20. -20.]
# yt : [INFO     ] 2022-02-15 12:21:30,986 Parameters: domain_right_edge         = [20. 20. 20.]
# yt : [INFO     ] 2022-02-15 12:21:30,986 Parameters: cosmological_simulation   = 0
# snapshot_0003
# snapshot_0004
# snapshot_0005

# %%
len(ds_Gall)
# Out:
# 24

# %% [markdown]
# # Extracting the data --

# %%
Idx=0
ds_Gall[Idx].length_unit.to('cm')
# Out:
# unyt_quantity(3.08568e+19, 'cm')

# %%
from os import listdir
listdir(sim_dir2)
# Out:
# ['snapshot_0001',
#  'snapshot_0000',
#  'snapshot_0005',
#  'snapshot_0002',
#  'snapshot_0003',
#  'snapshot_0004',
#  'parameters-usedvalues']

# %%
ds_Gall
# Out:
# [GadgetDataset: all_aciis_0/snapshot_0000,
#  GadgetDataset: all_aciis_0/snapshot_0001,
#  GadgetDataset: all_aciis_0/snapshot_0002,
#  GadgetDataset: all_aciis_0/snapshot_0003,
#  GadgetDataset: all_aciis_0/snapshot_0004,
#  GadgetDataset: all_aciis_0/snapshot_0005,
#  GadgetDataset: all_aciis_1/snapshot_0000,
#  GadgetDataset: all_aciis_1/snapshot_0001,
#  GadgetDataset: all_aciis_1/snapshot_0002,
#  GadgetDataset: all_aciis_1/snapshot_0003,
#  GadgetDataset: all_aciis_1/snapshot_0004,
#  GadgetDataset: all_aciis_1/snapshot_0005,
#  GadgetDataset: all_aciis_2/snapshot_0000,
#  GadgetDataset: all_aciis_2/snapshot_0001,
#  GadgetDataset: all_aciis_2/snapshot_0002,
#  GadgetDataset: all_aciis_2/snapshot_0003,
#  GadgetDataset: all_aciis_2/snapshot_0004,
#  GadgetDataset: all_aciis_2/snapshot_0005,
#  GadgetDataset: all_aciis_3/snapshot_0000,
#  GadgetDataset: all_aciis_3/snapshot_0001,
#  GadgetDataset: all_aciis_3/snapshot_0002,
#  GadgetDataset: all_aciis_3/snapshot_0003,
#  GadgetDataset: all_aciis_3/snapshot_0004,
#  GadgetDataset: all_aciis_3/snapshot_0005]

# %%
rhos=[]
vels=[]
rs=[]
## ---------------------------------------------------------
for Idx,k in enumerate(ds_Gall):
    rhos1 = ds_Gall[Idx].r["Gas", "Density"]
    rs1 = ds_Gall[Idx].r["all", "radius"]/Rad0
    print(Idx)
    if Idx == 0:
        vs1 = ds_Gall[Idx].r["all", "radial_velocity"]/Vel00
    else:
        vs1 = ds_Gall[Idx].r["all", "radial_velocity"]/Vel0
        
    rhos.append(rhos1)
    vels.append(vs1)
    rs.append(rs1)
# Out:
# yt : [INFO     ] 2022-02-15 12:21:35,499 Allocating for 2.332e+04 particles
# 0
# 1
# 2
# 3
# 4
# yt : [INFO     ] 2022-02-15 12:21:50,515 Allocating for 3.703e+04 particles
# 5
# 6
# 7
# 8
# 9
# 10
# yt : [INFO     ] 2022-02-15 12:22:05,932 Allocating for 6.401e+04 particles
# 11
# 12
# 13
# 14
# 15
# 16
# yt : [INFO     ] 2022-02-15 12:22:21,557 Allocating for 1.250e+05 particles
# 17
# 18
# 19
# 20
# 21
# 22
# 23

# %%
rs
# Out:
# [unyt_array([3.22975629, 3.09326487, 3.19822444, ..., 3.0634352 ,
#              2.92944792, 3.11687473], 'cm'),
#  unyt_array([3.22804112, 3.09139628, 3.19647568, ..., 3.06153034,
#              2.898824  , 3.11503411], 'cm'),
#  unyt_array([3.22392666, 3.08691139, 3.19227974, ..., 3.05695781,
#              2.86907384, 3.11061678], 'cm'),
#  unyt_array([3.21740645, 3.07980249, 3.18563021, ..., 3.04970972,
#              2.86473556, 3.10361529], 'cm'),
#  unyt_array([3.20847091, 3.0700576 , 3.17651697, ..., 3.03977324,
#              2.86281674, 3.09401815], 'cm'),
#  unyt_array([3.20847091, 3.0700576 , 3.17651697, ..., 3.03977324,
#              2.86281674, 3.09401815], 'cm'),
#  unyt_array([3.203909  , 3.1446461 , 3.20982173, ..., 3.07128455,
#              3.09958919, 3.11935859], 'cm'),
#  unyt_array([3.20216636, 3.14283762, 3.20808536, ..., 3.06938931,
#              3.09772814, 3.11752097], 'cm'),
#  unyt_array([3.19798527, 3.13849773, 3.20391967, ..., 3.06484012,
#              3.09326148, 3.11311063], 'cm'),
#  unyt_array([3.19135944, 3.13161959, 3.19731823, ..., 3.05762908,
#              3.0861817 , 3.10612033], 'cm'),
#  unyt_array([3.18227858, 3.1882709 , 3.19512316, ..., 3.04480432,
#              3.01307593, 3.07647667], 'cm'),
#  unyt_array([3.18227858, 3.1882709 , 3.19512316, ..., 3.04480432,
#              3.01307593, 3.07647667], 'cm'),
#  unyt_array([3.19745956, 3.22853901, 3.12271437, ..., 3.11990967,
#              3.23432274, 3.22652431], 'cm'),
#  unyt_array([3.22682255, 3.12088066, 3.19379316, ..., 3.11807264,
#              3.23261243, 3.22480575], 'cm'),
#  unyt_array([3.22270494, 3.11647974, 3.18959023, ..., 3.11366381,
#              3.22850945, 3.220683  ], 'cm'),
#  unyt_array([3.21617983, 3.10950441, 3.18292965, ..., 3.10667603,
#              3.22200783, 3.21414976], 'cm'),
#  unyt_array([3.25970449, 3.2072375 , 3.09994322, ..., 3.09709755,
#              3.2130976 , 3.20519632], 'cm'),
#  unyt_array([3.25970449, 3.2072375 , 3.09994322, ..., 3.09709755,
#              3.2130976 , 3.20519632], 'cm'),
#  unyt_array([3.24079201, 3.24899783, 3.25841348, ..., 3.24910325,
#              3.23152014, 3.2280176 ], 'cm'),
#  unyt_array([3.2390885 , 3.24730281, 3.25672814, ..., 3.24740845,
#              3.22980686, 3.22630062], 'cm'),
#  unyt_array([3.24323683, 3.26312344, 3.25268563, ..., 3.22569675,
#              3.24334251, 3.22218169], 'cm'),
#  unyt_array([3.22852598, 3.23679364, 3.2596521 , ..., 3.23689978,
#              3.21565444, 3.26106805], 'cm'),
#  unyt_array([3.25382755, 3.23750112, 3.15948441, ..., 3.21025804,
#              3.2280708 , 3.25782459], 'cm'),
#  unyt_array([3.25382755, 3.23750112, 3.15948441, ..., 3.21025804,
#              3.2280708 , 3.25782459], 'cm')]

# %% [markdown]
# # Bondi numerically in Python

# %%
from IPython.display import display, Math, Latex
import numpy as np
np.seterr(divide='ignore', invalid='ignore')

# %matplotlib inline
import matplotlib
import matplotlib.pyplot as plt

# %%
def plotBondiVelIndi(n,rb,velb,lbs,i):
    ## --- Estilo --
    putStyle(14,2,True,True)
    ## -------------
    ## ---
    plt.scatter(rb, velb, 2, label=str(lbs)+' $\gamma$= '+str(n)+' t~'+str(i))
    ## ----------------------------------------------------
    plt.legend(loc='best')
    plt.xlabel(r'$r~(u.c)$')
    ## Limits--
    plt.xscale("log")
    plt.xlim(0.005,5.1)
    plt.ylabel(r'$v_r~(u.c)$')
    plt.ylim(-50,5)

# %% [markdown]
# # n -> infty ... Isothermal $\gamma$ = 1

# %% [markdown]
# ## Creo arreglo de rhos y vels

# %%
rbArr=[]
VelbArr=[]
## ---- Rhos ----------------------------------------------------------------
RhobArr=[]
## -- version rapida:
nro1=[133000,133000,133000,133000,133000,133000,
      334000,334000,334000,334000,334000,334000,
      990900,990900,990900,990900,990900,990900,
      3500000,3500000,3500000,3500000,3500000,3500000,
      3500000,3500000,3500000,3500000,3500000,3500000]
#--
for i,(j,k,l) in enumerate(zip(rs,vels,rhos)):
    print(i, nro1[i], len(j.value))
#--
    idx1 = np.random.choice(np.arange(len(j.value)), len(j.value)-1, replace=False)
    rb, velb, rhob = j.value[idx1], k.value[idx1], l.value[idx1]
    rbArr.append(rb)
    VelbArr.append(velb)
    RhobArr.append(rhob)
# Out:
# 0 133000 23322
# 1 133000 23322
# 2 133000 23322
# 3 133000 23322
# 4 133000 23322
# 5 133000 23322
# 6 334000 37031
# 7 334000 37031
# 8 334000 37031
# 9 334000 37031
# 10 334000 37031
# 11 334000 37031
# 12 990900 64012
# 13 990900 64012
# 14 990900 64012
# 15 990900 64012
# 16 990900 64012
# 17 990900 64012
# 18 3500000 124987
# 19 3500000 124987
# 20 3500000 124987
# 21 3500000 124987
# 22 3500000 124987
# 23 3500000 124987

# %%
print("Time unit: ", ds_Gall[0].time_unit.in_units("kyr"))
# Out:
# Time unit:  149.0892633095566 kyr

# %%
ds_Gall
# Out:
# [GadgetDataset: all_aciis_0/snapshot_0000,
#  GadgetDataset: all_aciis_0/snapshot_0001,
#  GadgetDataset: all_aciis_0/snapshot_0002,
#  GadgetDataset: all_aciis_0/snapshot_0003,
#  GadgetDataset: all_aciis_0/snapshot_0004,
#  GadgetDataset: all_aciis_0/snapshot_0005,
#  GadgetDataset: all_aciis_1/snapshot_0000,
#  GadgetDataset: all_aciis_1/snapshot_0001,
#  GadgetDataset: all_aciis_1/snapshot_0002,
#  GadgetDataset: all_aciis_1/snapshot_0003,
#  GadgetDataset: all_aciis_1/snapshot_0004,
#  GadgetDataset: all_aciis_1/snapshot_0005,
#  GadgetDataset: all_aciis_2/snapshot_0000,
#  GadgetDataset: all_aciis_2/snapshot_0001,
#  GadgetDataset: all_aciis_2/snapshot_0002,
#  GadgetDataset: all_aciis_2/snapshot_0003,
#  GadgetDataset: all_aciis_2/snapshot_0004,
#  GadgetDataset: all_aciis_2/snapshot_0005,
#  GadgetDataset: all_aciis_3/snapshot_0000,
#  GadgetDataset: all_aciis_3/snapshot_0001,
#  GadgetDataset: all_aciis_3/snapshot_0002,
#  GadgetDataset: all_aciis_3/snapshot_0003,
#  GadgetDataset: all_aciis_3/snapshot_0004,
#  GadgetDataset: all_aciis_3/snapshot_0005]

# %%
for i,ds1 in enumerate(ds_Gall):
    print(i, ds1)
# Out:
# 0 snapshot_0000
# 1 snapshot_0001
# 2 snapshot_0002
# 3 snapshot_0003
# 4 snapshot_0004
# 5 snapshot_0005
# 6 snapshot_0000
# 7 snapshot_0001
# 8 snapshot_0002
# 9 snapshot_0003
# 10 snapshot_0004
# 11 snapshot_0005
# 12 snapshot_0000
# 13 snapshot_0001
# 14 snapshot_0002
# 15 snapshot_0003
# 16 snapshot_0004
# 17 snapshot_0005
# 18 snapshot_0000
# 19 snapshot_0001
# 20 snapshot_0002
# 21 snapshot_0003
# 22 snapshot_0004
# 23 snapshot_0005

# %% [markdown]
# # Gamma = 1

# %% [markdown]
# # CS64

# %%
n=1
# CS64
model1='CS64;'
nMod='1_1'
Idx1=0; Idx2=1; Idx3=2; Idx4=3;  
Idx5=4; Idx6=5; Idx7=6;

## -- Tiempo del ultimo --
myUnit1='kyr'
LastTime1=ds_Gall[Idx1].time_unit.in_units(myUnit1)
LastTime1=round(LastTime1.item(0))*0.0
## --
LastTime2=ds_Gall[Idx2].time_unit.in_units(myUnit1)
LastTime2=round(LastTime2.item(0))*0.05
## --
LastTime3=ds_Gall[Idx3].time_unit.in_units(myUnit1)
LastTime3=round(LastTime3.item(0))*0.1
## --
LastTime4=ds_Gall[Idx4].time_unit.in_units(myUnit1)
LastTime4=round(LastTime4.item(0))*0.15
## --
LastTime5=ds_Gall[Idx5].time_unit.in_units(myUnit1)
LastTime5=round(LastTime5.item(0))*0.2
## --

## ----- Las imagenes --
img1=plotBondiVelIndi(n,rbArr[Idx1],VelbArr[Idx1],model1,str(LastTime1)+' '+myUnit1)
img2=plotBondiVelIndi(n,rbArr[Idx2],VelbArr[Idx2],model1,str(LastTime2)+' '+myUnit1)
img3=plotBondiVelIndi(n,rbArr[Idx3],VelbArr[Idx3],model1,str(LastTime3)+' '+myUnit1)
img4=plotBondiVelIndi(n,rbArr[Idx4],VelbArr[Idx4],model1,str(LastTime4)+' '+myUnit1)
img5=plotBondiVelIndi(n,rbArr[Idx5],VelbArr[Idx5],model1,str(LastTime5)+' '+myUnit1)

# %% [markdown]
# # Cortes transversales ---

# %%
# ?annotate_timestamp
# Out:
# Object `annotate_timestamp` not found.

# %%
print("Time unit: ", ds_Gall[1].time_unit.in_units("kyr"))
# Out:
# Time unit:  149.0892633095566 kyr

# %%
ds_Gall[4]
# Out:
# GadgetDataset: all_aciis_0/snapshot_0004

# %%
Idx = 4
myUnit1='kyr'
LastTime1=ds_Gall[Idx].time_unit.in_units(myUnit1)
LastTime1=round(LastTime1.item(0))*0.2
model1='CS64-1'


ad = ds_Gall[Idx].all_data()
### Aqui defino --
density = ad[("Gas","Density")]
internal= ad[("Gas","InternalEnergy")]

#####
wdens = np.where(density == np.max(density))
coordinates = ad[("Gas","Coordinates")]
center = coordinates[wdens][0]
print('center = ',center)

### Nueva caja
new_box_size = ds_Gall[Idx].quan(2.5,'code_length')
left_edge = center - new_box_size/2
right_edge = center + new_box_size/2

print('Este es el box: ', new_box_size.in_units('pc'))
print(left_edge.in_units('pc'))
print(right_edge.in_units('pc'))

#####
px = yt.SlicePlot(ds_Gall[Idx], 'z', ('gas', 'density'), 
#center=[0.,new_box_size/2,new_box_size/2], width=new_box_size,
#origin='lower-left-window')
center=[0,0,0], width=new_box_size,
origin='center-window') #'lower-left-window'
px.set_unit('x','code_length')
px.set_unit('y','code_length')
px.set_unit(("gas", "density"),'code_density')
px.set_cmap(field="density", cmap='jet') ## amfhot,jet



px.annotate_text((-.5,.5), "(a) "+model1+'; t= '+str(LastTime1)+' '+myUnit1, 
                 coord_system="plot",
                 text_args={"color": "white", "size":26,
                           'family': 'sans-serif', 
                           'style': 'italic'})
# Out:
# yt : [INFO     ] 2022-02-15 12:23:27,052 xlim = -1.250000 1.250000
# yt : [INFO     ] 2022-02-15 12:23:27,053 ylim = -1.250000 1.250000
# yt : [INFO     ] 2022-02-15 12:23:27,054 xlim = -1.250000 1.250000
# yt : [INFO     ] 2022-02-15 12:23:27,055 ylim = -1.250000 1.250000
# yt : [INFO     ] 2022-02-15 12:23:27,056 Making a fixed resolution buffer of (('gas', 'density')) 800 by 800
# center =  [-1.66451871 -1.67051518  1.62310696] code_length
# Este es el box:  25.000019598918 pc
# [-29.14520999 -29.20517469   3.73107249] pc
# [-4.14519039 -4.20515509 28.73109209] pc
# /Users/josem/Desktop/Peiskos2020/CursoVAE101_v1/VAEtf1env/lib/python3.8/site-packages/yt/data_objects/data_containers.py:1421: VisibleDeprecationWarning: The requested field name 'x' is ambiguous and corresponds to any one of the following field types:
#  {'Gas', 'all', 'gas'}
# Please specify the requested field as an explicit tuple (ftype, fname).
# Defaulting to '("gas", "x")'.
# Deprecated since v4.0.0. This feature will be removed in v4.1.0
#   finfo = self.ds._get_field_info(field)
# yt : [INFO     ] 2022-02-15 12:23:28,571 Making a fixed resolution buffer of (('gas', 'x')) 800 by 800
# /Users/josem/Desktop/Peiskos2020/CursoVAE101_v1/VAEtf1env/lib/python3.8/site-packages/yt/data_objects/data_containers.py:1421: VisibleDeprecationWarning: The requested field name 'y' is ambiguous and corresponds to any one of the following field types:
#  {'Gas', 'all', 'gas'}
# Please specify the requested field as an explicit tuple (ftype, fname).
# Defaulting to '("gas", "y")'.
# Deprecated since v4.0.0. This feature will be removed in v4.1.0
#   finfo = self.ds._get_field_info(field)
# yt : [INFO     ] 2022-02-15 12:23:29,483 Making a fixed resolution buffer of (('gas', 'y')) 800 by 800
# /Users/josem/Desktop/Peiskos2020/CursoVAE101_v1/VAEtf1env/lib/python3.8/site-packages/yt/data_objects/data_containers.py:1421: VisibleDeprecationWarning: The requested field name 'density' is ambiguous and corresponds to any one of the following field types:
#  {'all', 'gas'}
# Please specify the requested field as an explicit tuple (ftype, fname).
# Defaulting to '("gas", "density")'.
# Deprecated since v4.0.0. This feature will be removed in v4.1.0
#   finfo = self.ds._get_field_info(field)
# <img style="max-width:100%;max-height:100%;" src="data:image/png;base64,..."><br>

# %%
px.save()
# Out:
# yt : [INFO     ] 2022-02-15 12:23:35,628 Saving plot snapshot_0004_Slice_z_density.png
# ['snapshot_0004_Slice_z_density.png']

# %%
px.save()

# %%
#import pickle4 as pickle
#!pip install pickle4

# %%
#import dill
#dill.dump_session('./notebook_env.db')

# %%
    #px = yt.SlicePlot(ds, 'x', ('gas', 'density'), width=new_box_size)
    px.set_font({'family': 'sans-serif', 'style': 'italic',
    'weight': 'bold', 'size': 16})
    #px.set_log('density', True, linthresh=1.e-49)
    #px.set_unit('time','code_time')
    #px.annotate_quiver('velocity_z', 'velocity_y', 40)
    #px.annotate_velocity()
    # Ensure the colorbar limits match for all plots
    px.annotate_timestamp(corner='upper_left')
    #px.annotate_scale(corner='upper_right', unit='pc')
    px.set_cmap(field="density", cmap='jet') ## amfhot,jet
    name = os.path.join(sim_dir1+('%s' % ds))
    #px.save(name=name, suffix="eps")
    ###############################################
    ###############################################

# %%
px

# %%
p = yt.ProjectionPlot(ds, "y", ("gas", "density"))
p.show()

# %%
p.pan_rel((0.1, 0.0))

# %% [markdown]
# # Solving and Plotting semi-Analytical solutions

# %%
TX=1.e7
pc = 3.18e+18
BOLTZMANN  = 1.3806e-16
PROTONMASS = 1.6726e-24
HYDROGEN_MASSFRAC = 0.625
mass_sun = 1.989e+33  ## g
RHO0 = 1.0e-19        ## Density at infty
Gnew = 6.672e-8       ##
myPI = 3.14159
Mbh  = 1.e+8*mass_sun ## Black hole mass
## --
#Rad0 = 3.08568025e+19 ## cm (10pc)
myGamma=1.

## 
Uvel = np.sqrt((myGamma * BOLTZMANN * TX)/(HYDROGEN_MASSFRAC*PROTONMASS))
Uvel
# Out:
# 36341084.17671472

# %%
Rb=Gnew* Mbh/(Uvel*Uvel) #3.*(Mbh/(1.e+8*mass_sun))/(TX/1.e+7)
FactX=Rb/(Rad0)
FactX
# Out:
# 0.3256448211948118

# %% [markdown]
# # Isothermal Model

# %%
with open('../Profiles_G1_v5.txt') as f:
    lines = f.readlines()

# %%
lines[:10]
# Out:
# ['0.00500\t19.6094707874\t2285.4717085060\n',
#  '0.00600\t17.8439139149\t1744.1712011540\n',
#  '0.00700\t16.4694416177\t1388.3749731020\n',
#  '0.00800\t15.3597798998\t1139.7688017180\n',
#  '0.00900\t14.4392725456\t957.9688748291\n',
#  '0.01000\t13.6594572447\t820.2538706454\n',
#  '0.01100\t12.9876606813\t712.9604313727\n',
#  '0.01200\t12.4009437556\t627.4288751636\n',
#  '0.01300\t11.8826629917\t557.9319689774\n',
#  '0.01400\t11.4204090922\t500.5460044881\n']

# %%
Fact1=3.25 #
Fact2=0.001

xIso=[]
MIso=[]
RhoIso=[]
for line in lines[5:]:
    xIso.append(FactX*np.float(line.split('\t')[0]))
    MIso.append(-Fact1*np.float(np.float(line.split('\t')[1])))
    RhoIso.append(Fact2 * np.float(np.float(line.split('\t')[2])))
#MIso

# %%
from scipy import interpolate

def plotBondiVelRatio(n,rb,velb,lbs,i):
    ## --- Estilo --
    #plt.figure(figsize=(8,2))
    putStyle(14,2,True,True)
    ## -------------
    # Interpolation
    temp = interpolate.interp1d(xIso, MIso)
    ## ---
    ynew = temp(rb[np.where(rb < np.max(xIso))])
    xnew = rb[np.where(rb < np.max(xIso))]
    
    
    plt.scatter(xnew, (velb[np.where(rb < np.max(xIso))] - ynew), 2)
    #           2, label=str(lbs)+' $\gamma$= '+str(n)+' t~'+str(i))
    plt.axhline(y = 0., color = 'black', linestyle = '--')
    ## ----------------------------------------------------
    #plt.legend(loc='best')
    plt.xlabel(r'$r~(u.c)$')
    ## Limits--
    plt.xscale("log")
    plt.xlim(0.005, 5.1)
    plt.ylabel(r'Diff')
    plt.ylim(-5, 5)

# %% [markdown]
# # CS64 -1

# %%
# plt.xscale("log")
plt.figure(figsize=(8,3))

n=1
# CS64-1
model1='CS64-1'
nMod='Final_Fig1'
Idx1=0; Idx2=1; Idx3=2; Idx4=3;  
Idx5=4; Idx6=5; Idx7=6;

## -- Tiempo del ultimo --
myUnit1='kyr'
LastTime1=ds_Gall[Idx1].time_unit.in_units(myUnit1)
LastTime1=round(LastTime1.item(0))*0.0
## --
LastTime2=ds_Gall[Idx2].time_unit.in_units(myUnit1)
LastTime2=round(LastTime2.item(0))*0.05
## --
LastTime3=ds_Gall[Idx3].time_unit.in_units(myUnit1)
LastTime3=round(LastTime3.item(0))*0.1
## --
LastTime4=ds_Gall[Idx4].time_unit.in_units(myUnit1)
LastTime4=round(LastTime4.item(0))*0.15
## --
LastTime5=ds_Gall[Idx5].time_unit.in_units(myUnit1)
LastTime5=round(LastTime5.item(0))*0.2
## --



## ----- Las imagenes --
img2=plotBondiVelRatio(n,rbArr[Idx2],VelbArr[Idx2],model1,str(LastTime2)+' '+myUnit1)
img3=plotBondiVelRatio(n,rbArr[Idx3],VelbArr[Idx3],model1,str(LastTime3)+' '+myUnit1)
img4=plotBondiVelRatio(n,rbArr[Idx4],VelbArr[Idx4],model1,'1.35'+' '+myUnit1)
img5=plotBondiVelRatio(n,rbArr[Idx5],VelbArr[Idx5],model1,str(LastTime5)+' '+myUnit1)


plt.savefig(str(model1)+'_'+str(nMod)+'_Vel_Diff_v1.png')

# %%
plt.xscale("log")
#plt.figure(figsize=(8,6))

n=1
plt.plot(xIso,MIso,'black', 
         label='$\gamma$= '+str(n)+'; Theoretical - Ramirez etal. 2021')


# CS64-1
model1='CS64-1'
nMod='Final_Fig1'
Idx1=0; Idx2=1; Idx3=2; Idx4=3;  
Idx5=4; Idx6=5; Idx7=6;

## -- Tiempo del ultimo --
myUnit1='kyr'
## --
LastTime2=ds_Gall[Idx2].time_unit.in_units(myUnit1)
LastTime2=round(LastTime2.item(0))*0.05
## --
LastTime3=ds_Gall[Idx3].time_unit.in_units(myUnit1)
LastTime3=round(LastTime3.item(0))*0.1
## --
LastTime4=ds_Gall[Idx4].time_unit.in_units(myUnit1)
LastTime4=round(LastTime4.item(0)*0.15)
## --
LastTime5=ds_Gall[Idx5].time_unit.in_units(myUnit1)
LastTime5=round(LastTime5.item(0))*0.2
## --



## ----- Las imagenes --
img2=plotBondiVelIndi(n,rbArr[Idx2],VelbArr[Idx2],model1,str(LastTime2)+' '+myUnit1)
img3=plotBondiVelIndi(n,rbArr[Idx3],VelbArr[Idx3],model1,str(LastTime3)+' '+myUnit1)
img4=plotBondiVelIndi(n,rbArr[Idx4],VelbArr[Idx4],model1,str(LastTime4)+' '+myUnit1)
img5=plotBondiVelIndi(n,rbArr[Idx5],VelbArr[Idx5],model1,str(LastTime5)+' '+myUnit1)


plt.savefig(str(model1)+'_'+str(nMod)+'_Vel_v1.png')

# %% [markdown]
# # CS64-2

# %%
# plt.xscale("log")
plt.figure(figsize=(8,3))

n=1
#plt.plot(xIso,MIso,'blue', 
#         label='$\gamma$= '+str(n)+'; Theoretical - Ramirez etal. 2021')


# W256
model1='CS64-2'
nMod='Final_Fig1'
Idx1=6; Idx2=7; Idx3=8; Idx4=9;  
Idx5=10; Idx6=11;

## -- Tiempo del ultimo --
myUnit1='kyr'
LastTime1=ds_Gall[Idx1].time_unit.in_units(myUnit1)
LastTime1=round(LastTime1.item(0))*0.0
## --
LastTime2=ds_Gall[Idx2].time_unit.in_units(myUnit1)
LastTime2=round(LastTime2.item(0))*0.05
## --
LastTime3=ds_Gall[Idx3].time_unit.in_units(myUnit1)
LastTime3=round(LastTime3.item(0))*0.1
## --
LastTime4=ds_Gall[Idx4].time_unit.in_units(myUnit1)
LastTime4=round(LastTime4.item(0))*0.15
## --
LastTime5=ds_Gall[Idx5].time_unit.in_units(myUnit1)
LastTime5=round(LastTime5.item(0))*0.2
## --



## ----- Las imagenes --
img2=plotBondiVelRatio(n,rbArr[Idx2],VelbArr[Idx2],model1,str(LastTime2)+' '+myUnit1)
img3=plotBondiVelRatio(n,rbArr[Idx3],VelbArr[Idx3],model1,str(LastTime3)+' '+myUnit1)
img4=plotBondiVelRatio(n,rbArr[Idx4],VelbArr[Idx4],model1,'22.4'+' '+myUnit1)
img5=plotBondiVelRatio(n,rbArr[Idx5],VelbArr[Idx5],model1,str(LastTime5)+' '+myUnit1)


plt.savefig(str(model1)+'_'+str(nMod)+'_Vel_Diff_v1.png')

# %%
plt.xscale("log")
#plt.figure(figsize=(8,6))

n=1
plt.plot(xIso,MIso,'black', 
         label='$\gamma$= '+str(n)+'; Theoretical - Ramirez etal. 2021')


# W256
model1='CS64-2'
nMod='Final_Fig1'
Idx1=6; Idx2=7; Idx3=8; Idx4=9;  
Idx5=10; Idx6=11;

## -- Tiempo del ultimo --
myUnit1='kyr'
LastTime1=ds_Gall[Idx1].time_unit.in_units(myUnit1)
LastTime1=round(LastTime1.item(0))*0.0
## --
LastTime2=ds_Gall[Idx2].time_unit.in_units(myUnit1)
LastTime2=round(LastTime2.item(0))*0.05
## --
LastTime3=ds_Gall[Idx3].time_unit.in_units(myUnit1)
LastTime3=round(LastTime3.item(0))*0.1
## --
LastTime4=ds_Gall[Idx4].time_unit.in_units(myUnit1)
LastTime4=round(LastTime4.item(0)*0.15)
## --
LastTime5=ds_Gall[Idx5].time_unit.in_units(myUnit1)
LastTime5=round(LastTime5.item(0))*0.2
## --



## ----- Las imagenes --
img2=plotBondiVelIndi(n,rbArr[Idx2],VelbArr[Idx2],model1,str(LastTime2)+' '+myUnit1)
img3=plotBondiVelIndi(n,rbArr[Idx3],VelbArr[Idx3],model1,str(LastTime3)+' '+myUnit1)
img4=plotBondiVelIndi(n,rbArr[Idx4],VelbArr[Idx4],model1,str(LastTime4)+' '+myUnit1)
img5=plotBondiVelIndi(n,rbArr[Idx5],VelbArr[Idx5],model1,str(LastTime5)+' '+myUnit1)


plt.savefig(str(model1)+'_'+str(nMod)+'_Vel_v1.png')

# %% [markdown]
# # CS64-3

# %%
# plt.xscale("log")
plt.figure(figsize=(8,3))

n=1
#plt.plot(xIso,MIso,'blue', 
#         label='$\gamma$= '+str(n)+'; Theoretical - Ramirez etal. 2021')


# W256
model1='CS64-3'
nMod='Final_Fig1'
Idx1=12; Idx2=13; Idx3=14; Idx4=15;  
Idx5=16; Idx6=17;

## -- Tiempo del ultimo --
myUnit1='kyr'
LastTime1=ds_Gall[Idx1].time_unit.in_units(myUnit1)
LastTime1=round(LastTime1.item(0))*0.0
## --
LastTime2=ds_Gall[Idx2].time_unit.in_units(myUnit1)
LastTime2=round(LastTime2.item(0))*0.05
## --
LastTime3=ds_Gall[Idx3].time_unit.in_units(myUnit1)
LastTime3=round(LastTime3.item(0))*0.1
## --
LastTime4=ds_Gall[Idx4].time_unit.in_units(myUnit1)
LastTime4=round(LastTime4.item(0)*0.15)
## --
LastTime5=ds_Gall[Idx5].time_unit.in_units(myUnit1)
LastTime5=round(LastTime5.item(0))*0.2
## --



## ----- Las imagenes --
img2=plotBondiVelRatio(n,rbArr[Idx2],VelbArr[Idx2],model1,str(LastTime2)+' '+myUnit1)
img3=plotBondiVelRatio(n,rbArr[Idx3],VelbArr[Idx3],model1,str(LastTime3)+' '+myUnit1)
img4=plotBondiVelRatio(n,rbArr[Idx4],VelbArr[Idx4],model1,'22.4'+' '+myUnit1)
img5=plotBondiVelRatio(n,rbArr[Idx5],VelbArr[Idx5],model1,str(LastTime5)+' '+myUnit1)


plt.savefig(str(model1)+'_'+str(nMod)+'_Vel_Diff_v1.png')

# %%
plt.xscale("log")
#plt.figure(figsize=(8,6))

n=1
plt.plot(xIso,MIso,'black', 
         label='$\gamma$= '+str(n)+'; Theoretical - Ramirez etal. 2021')


# W256
model1='CS64-3'
nMod='Final_Fig1'
Idx1=12; Idx2=13; Idx3=14; Idx4=15;  
Idx5=16; Idx6=17;

## -- Tiempo del ultimo --
myUnit1='kyr'
LastTime1=ds_Gall[Idx1].time_unit.in_units(myUnit1)
LastTime1=round(LastTime1.item(0))*0.0
## --
LastTime2=ds_Gall[Idx2].time_unit.in_units(myUnit1)
LastTime2=round(LastTime2.item(0))*0.05
## --
LastTime3=ds_Gall[Idx3].time_unit.in_units(myUnit1)
LastTime3=round(LastTime3.item(0))*0.1
## --
LastTime4=ds_Gall[Idx4].time_unit.in_units(myUnit1)
LastTime4=round(LastTime4.item(0)*0.15)
## --
LastTime5=ds_Gall[Idx5].time_unit.in_units(myUnit1)
LastTime5=round(LastTime5.item(0))*0.2
## --



## ----- Las imagenes --
img2=plotBondiVelIndi(n,rbArr[Idx2],VelbArr[Idx2],model1,str(LastTime2)+' '+myUnit1)
img3=plotBondiVelIndi(n,rbArr[Idx3],VelbArr[Idx3],model1,str(LastTime3)+' '+myUnit1)
img4=plotBondiVelIndi(n,rbArr[Idx4],VelbArr[Idx4],model1,str(LastTime4)+' '+myUnit1)
img5=plotBondiVelIndi(n,rbArr[Idx5],VelbArr[Idx5],model1,str(LastTime5)+' '+myUnit1)


plt.savefig(str(model1)+'_'+str(nMod)+'_Vel_v1.png')

# %% [markdown]
# # CS64-4

# %%
# plt.xscale("log")
plt.figure(figsize=(8,3))

n=1
#plt.plot(xIso,MIso,'blue', 
#         label='$\gamma$= '+str(n)+'; Theoretical - Ramirez etal. 2021')


# W256
model1='CS64-4'
nMod='Final_Fig1'
Idx1=18; Idx2=19; Idx3=20; Idx4=21;  
Idx5=22; Idx6=23;

## -- Tiempo del ultimo --
myUnit1='kyr'
LastTime1=ds_Gall[Idx1].time_unit.in_units(myUnit1)
LastTime1=round(LastTime1.item(0))*0.0
## --
LastTime2=ds_Gall[Idx2].time_unit.in_units(myUnit1)
LastTime2=round(LastTime2.item(0))*0.05
## --
LastTime3=ds_Gall[Idx3].time_unit.in_units(myUnit1)
LastTime3=round(LastTime3.item(0))*0.1
## --
LastTime4=ds_Gall[Idx4].time_unit.in_units(myUnit1)
LastTime4=round(LastTime4.item(0)*0.15)
## --
LastTime5=ds_Gall[Idx5].time_unit.in_units(myUnit1)
LastTime5=round(LastTime5.item(0))*0.2
## --



## ----- Las imagenes --
img2=plotBondiVelRatio(n,rbArr[Idx2],VelbArr[Idx2],model1,str(LastTime2)+' '+myUnit1)
img3=plotBondiVelRatio(n,rbArr[Idx3],VelbArr[Idx3],model1,str(LastTime3)+' '+myUnit1)
img4=plotBondiVelRatio(n,rbArr[Idx4],VelbArr[Idx4],model1,'22.4'+' '+myUnit1)
img5=plotBondiVelRatio(n,rbArr[Idx5],VelbArr[Idx5],model1,str(LastTime5)+' '+myUnit1)


plt.savefig(str(model1)+'_'+str(nMod)+'_Vel_Diff_v1.png')

# %%
plt.xscale("log")
#plt.figure(figsize=(8,6))

n=1
plt.plot(xIso,MIso,'black', 
         label='$\gamma$= '+str(n)+'; Theoretical - Ramirez etal. 2021')


# W256
model1='CS64-4'
nMod='Final_Fig1'
Idx1=18; Idx2=19; Idx3=20; Idx4=21;  
Idx5=22; Idx6=23;

## -- Tiempo del ultimo --
myUnit1='kyr'
LastTime1=ds_Gall[Idx1].time_unit.in_units(myUnit1)
LastTime1=round(LastTime1.item(0))*0.0
## --
LastTime2=ds_Gall[Idx2].time_unit.in_units(myUnit1)
LastTime2=round(LastTime2.item(0))*0.05
## --
LastTime3=ds_Gall[Idx3].time_unit.in_units(myUnit1)
LastTime3=round(LastTime3.item(0))*0.1
## --
LastTime4=ds_Gall[Idx4].time_unit.in_units(myUnit1)
LastTime4=round(LastTime4.item(0)*0.15)
## --
LastTime5=ds_Gall[Idx5].time_unit.in_units(myUnit1)
LastTime5=round(LastTime5.item(0))*0.2
## --



## ----- Las imagenes --
img2=plotBondiVelIndi(n,rbArr[Idx2],VelbArr[Idx2],model1,str(LastTime2)+' '+myUnit1)
img3=plotBondiVelIndi(n,rbArr[Idx3],VelbArr[Idx3],model1,str(LastTime3)+' '+myUnit1)
img4=plotBondiVelIndi(n,rbArr[Idx4],VelbArr[Idx4],model1,str(LastTime4)+' '+myUnit1)
img5=plotBondiVelIndi(n,rbArr[Idx5],VelbArr[Idx5],model1,str(LastTime5)+' '+myUnit1)


plt.savefig(str(model1)+'_'+str(nMod)+'_Vel_v1.png')
