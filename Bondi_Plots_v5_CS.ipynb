# %% [markdown]
# # Frontiers, Bondi Eqs. with consistency

# %%
import yt
from yt.units import kpc
import numpy as np
import yt.visualization.eps_writer as eps
import matplotlib.pyplot as plt
from yt import derived_field
from matplotlib import pylab
from yt.mods import * # set up our namespace
from mpl_toolkits.axes_grid1 import AxesGrid
from os.path import exists

fig = plt.figure()
########################################

#### -----
def putStyle(sFont,syT,top1,R1):
    import matplotlib as mpl
    import matplotlib.style as style
    style.available

    # General plot parameters
    mpl.rcParams['font.family'] = 'Avenir'
    mpl.rcParams['font.size'] = sFont
    mpl.rcParams['axes.linewidth'] = 4
    mpl.rcParams['axes.spines.bottom'] = top1
    mpl.rcParams['axes.spines.right'] = R1
    mpl.rcParams['xtick.major.size'] = 10
    mpl.rcParams['xtick.major.width'] = 2
    mpl.rcParams['ytick.major.size'] = 10
    mpl.rcParams['ytick.major.width'] = syT
    mpl.rcParams['lines.linewidth']= 3
    mpl.rcParams["figure.figsize"] = (8,8)

# %%
## 10pc
Rad0=3.08568e+19
Vel00=6.55844e+06
Vel0=6.55844e+06 #


unit_base = {'UnitLength_in_cm'         :   Rad0,
             'UnitMass_in_g'            :   1.98892e+40,
             'UnitVelocity_in_cm_per_s' :   Vel0,
             'GravityConstantInternal'  :   0,
             }

bbox_lim = 20.0 #codelength

bbox = [[-bbox_lim,bbox_lim],
        [-bbox_lim,bbox_lim],
        [-bbox_lim,bbox_lim]]

# %%
### --
### Directorio de la simulacion!!!--- ###############################################
sim_dir1="./all_aciis_0/"
sim_dir2="./all_aciis_1/"
sim_dir3="./all_aciis_2/"
sim_dir4="./all_aciis_3/"

sim_Gen=[sim_dir1, sim_dir2, sim_dir3, sim_dir4]
#####################################################################################

### Finalmente levanto la data!!--
#######################################

ds_Gall=[]

## 2 loops--
for k in sim_Gen:
### G11 Particles!!--
    for i in range(0,1001):
        if i<10: fn = k+"snapshot_000%i" % i
        if i >10 and i<100: fn = k+"snapshot_00%i" % i
        if i>100 and i<1000: fn = k+"snapshot_0%i" % i
            
        if exists(fn):
            dt = yt.load(fn,
                unit_base=unit_base,  ## -- No voy a override the units. Take them from the file
                bounding_box=bbox)
            ###
            ds_Gall.append(dt)
            print(dt)
    #######################################
    #######################################
# Out:
# yt : [INFO     ] 2022-02-16 09:43:12,997 Omega Lambda is 0.0, so we are turning off Cosmology.
# yt : [INFO     ] 2022-02-16 09:43:13,067 Parameters: current_time              = 0.0
# yt : [INFO     ] 2022-02-16 09:43:13,068 Parameters: domain_dimensions         = [1 1 1]
# yt : [INFO     ] 2022-02-16 09:43:13,068 Parameters: domain_left_edge          = [-20. -20. -20.]
# yt : [INFO     ] 2022-02-16 09:43:13,069 Parameters: domain_right_edge         = [20. 20. 20.]
# yt : [INFO     ] 2022-02-16 09:43:13,070 Parameters: cosmological_simulation   = 0
# yt : [INFO     ] 2022-02-16 09:43:13,080 Omega Lambda is 0.0, so we are turning off Cosmology.
# yt : [INFO     ] 2022-02-16 09:43:13,145 Parameters: current_time              = 0.05
# yt : [INFO     ] 2022-02-16 09:43:13,146 Parameters: domain_dimensions         = [1 1 1]
# yt : [INFO     ] 2022-02-16 09:43:13,146 Parameters: domain_left_edge          = [-20. -20. -20.]
# yt : [INFO     ] 2022-02-16 09:43:13,147 Parameters: domain_right_edge         = [20. 20. 20.]
# yt : [INFO     ] 2022-02-16 09:43:13,148 Parameters: cosmological_simulation   = 0
# yt : [INFO     ] 2022-02-16 09:43:13,159 Omega Lambda is 0.0, so we are turning off Cosmology.
# yt : [INFO     ] 2022-02-16 09:43:13,222 Parameters: current_time              = 0.1
# yt : [INFO     ] 2022-02-16 09:43:13,223 Parameters: domain_dimensions         = [1 1 1]
# yt : [INFO     ] 2022-02-16 09:43:13,223 Parameters: domain_left_edge          = [-20. -20. -20.]
# yt : [INFO     ] 2022-02-16 09:43:13,224 Parameters: domain_right_edge         = [20. 20. 20.]
# yt : [INFO     ] 2022-02-16 09:43:13,225 Parameters: cosmological_simulation   = 0
# yt : [INFO     ] 2022-02-16 09:43:13,239 Omega Lambda is 0.0, so we are turning off Cosmology.
# snapshot_0000
# snapshot_0001
# snapshot_0002
# yt : [INFO     ] 2022-02-16 09:43:13,297 Parameters: current_time              = 0.15000000000000002
# yt : [INFO     ] 2022-02-16 09:43:13,298 Parameters: domain_dimensions         = [1 1 1]
# yt : [INFO     ] 2022-02-16 09:43:13,298 Parameters: domain_left_edge          = [-20. -20. -20.]
# yt : [INFO     ] 2022-02-16 09:43:13,299 Parameters: domain_right_edge         = [20. 20. 20.]
# yt : [INFO     ] 2022-02-16 09:43:13,299 Parameters: cosmological_simulation   = 0
# yt : [INFO     ] 2022-02-16 09:43:13,311 Omega Lambda is 0.0, so we are turning off Cosmology.
# yt : [INFO     ] 2022-02-16 09:43:13,365 Parameters: current_time              = 0.2
# yt : [INFO     ] 2022-02-16 09:43:13,366 Parameters: domain_dimensions         = [1 1 1]
# yt : [INFO     ] 2022-02-16 09:43:13,366 Parameters: domain_left_edge          = [-20. -20. -20.]
# yt : [INFO     ] 2022-02-16 09:43:13,367 Parameters: domain_right_edge         = [20. 20. 20.]
# yt : [INFO     ] 2022-02-16 09:43:13,368 Parameters: cosmological_simulation   = 0
# yt : [INFO     ] 2022-02-16 09:43:13,380 Omega Lambda is 0.0, so we are turning off Cosmology.
# yt : [INFO     ] 2022-02-16 09:43:13,437 Parameters: current_time              = 0.2
# yt : [INFO     ] 2022-02-16 09:43:13,438 Parameters: domain_dimensions         = [1 1 1]
# yt : [INFO     ] 2022-02-16 09:43:13,439 Parameters: domain_left_edge          = [-20. -20. -20.]
# yt : [INFO     ] 2022-02-16 09:43:13,439 Parameters: domain_right_edge         = [20. 20. 20.]
# yt : [INFO     ] 2022-02-16 09:43:13,440 Parameters: cosmological_simulation   = 0
# yt : [INFO     ] 2022-02-16 09:43:13,462 Omega Lambda is 0.0, so we are turning off Cosmology.
# yt : [INFO     ] 2022-02-16 09:43:13,517 Parameters: current_time              = 0.0
# snapshot_0003
# snapshot_0004
# snapshot_0005
# yt : [INFO     ] 2022-02-16 09:43:13,517 Parameters: domain_dimensions         = [1 1 1]
# yt : [INFO     ] 2022-02-16 09:43:13,518 Parameters: domain_left_edge          = [-20. -20. -20.]
# yt : [INFO     ] 2022-02-16 09:43:13,518 Parameters: domain_right_edge         = [20. 20. 20.]
# yt : [INFO     ] 2022-02-16 09:43:13,519 Parameters: cosmological_simulation   = 0
# yt : [INFO     ] 2022-02-16 09:43:13,528 Omega Lambda is 0.0, so we are turning off Cosmology.
# yt : [INFO     ] 2022-02-16 09:43:13,579 Parameters: current_time              = 0.05
# yt : [INFO     ] 2022-02-16 09:43:13,580 Parameters: domain_dimensions         = [1 1 1]
# yt : [INFO     ] 2022-02-16 09:43:13,580 Parameters: domain_left_edge          = [-20. -20. -20.]
# yt : [INFO     ] 2022-02-16 09:43:13,581 Parameters: domain_right_edge         = [20. 20. 20.]
# yt : [INFO     ] 2022-02-16 09:43:13,582 Parameters: cosmological_simulation   = 0
# yt : [INFO     ] 2022-02-16 09:43:13,594 Omega Lambda is 0.0, so we are turning off Cosmology.
# yt : [INFO     ] 2022-02-16 09:43:13,646 Parameters: current_time              = 0.1
# yt : [INFO     ] 2022-02-16 09:43:13,647 Parameters: domain_dimensions         = [1 1 1]
# yt : [INFO     ] 2022-02-16 09:43:13,647 Parameters: domain_left_edge          = [-20. -20. -20.]
# yt : [INFO     ] 2022-02-16 09:43:13,648 Parameters: domain_right_edge         = [20. 20. 20.]
# yt : [INFO     ] 2022-02-16 09:43:13,648 Parameters: cosmological_simulation   = 0
# yt : [INFO     ] 2022-02-16 09:43:13,659 Omega Lambda is 0.0, so we are turning off Cosmology.
# yt : [INFO     ] 2022-02-16 09:43:13,712 Parameters: current_time              = 0.15000000000000002
# yt : [INFO     ] 2022-02-16 09:43:13,713 Parameters: domain_dimensions         = [1 1 1]
# yt : [INFO     ] 2022-02-16 09:43:13,713 Parameters: domain_left_edge          = [-20. -20. -20.]
# yt : [INFO     ] 2022-02-16 09:43:13,714 Parameters: domain_right_edge         = [20. 20. 20.]
# yt : [INFO     ] 2022-02-16 09:43:13,715 Parameters: cosmological_simulation   = 0
# snapshot_0000
# snapshot_0001
# snapshot_0002
# snapshot_0003
# yt : [INFO     ] 2022-02-16 09:43:13,726 Omega Lambda is 0.0, so we are turning off Cosmology.
# yt : [INFO     ] 2022-02-16 09:43:13,781 Parameters: current_time              = 0.2
# yt : [INFO     ] 2022-02-16 09:43:13,781 Parameters: domain_dimensions         = [1 1 1]
# yt : [INFO     ] 2022-02-16 09:43:13,782 Parameters: domain_left_edge          = [-20. -20. -20.]
# yt : [INFO     ] 2022-02-16 09:43:13,783 Parameters: domain_right_edge         = [20. 20. 20.]
# yt : [INFO     ] 2022-02-16 09:43:13,784 Parameters: cosmological_simulation   = 0
# yt : [INFO     ] 2022-02-16 09:43:13,798 Omega Lambda is 0.0, so we are turning off Cosmology.
# yt : [INFO     ] 2022-02-16 09:43:13,858 Parameters: current_time              = 0.2
# yt : [INFO     ] 2022-02-16 09:43:13,858 Parameters: domain_dimensions         = [1 1 1]
# yt : [INFO     ] 2022-02-16 09:43:13,859 Parameters: domain_left_edge          = [-20. -20. -20.]
# yt : [INFO     ] 2022-02-16 09:43:13,860 Parameters: domain_right_edge         = [20. 20. 20.]
# yt : [INFO     ] 2022-02-16 09:43:13,860 Parameters: cosmological_simulation   = 0
# yt : [INFO     ] 2022-02-16 09:43:13,882 Omega Lambda is 0.0, so we are turning off Cosmology.
# yt : [INFO     ] 2022-02-16 09:43:13,937 Parameters: current_time              = 0.0
# yt : [INFO     ] 2022-02-16 09:43:13,937 Parameters: domain_dimensions         = [1 1 1]
# yt : [INFO     ] 2022-02-16 09:43:13,938 Parameters: domain_left_edge          = [-20. -20. -20.]
# yt : [INFO     ] 2022-02-16 09:43:13,939 Parameters: domain_right_edge         = [20. 20. 20.]
# yt : [INFO     ] 2022-02-16 09:43:13,939 Parameters: cosmological_simulation   = 0
# yt : [INFO     ] 2022-02-16 09:43:13,950 Omega Lambda is 0.0, so we are turning off Cosmology.
# yt : [INFO     ] 2022-02-16 09:43:14,005 Parameters: current_time              = 0.05
# snapshot_0004
# snapshot_0005
# snapshot_0000
# yt : [INFO     ] 2022-02-16 09:43:14,005 Parameters: domain_dimensions         = [1 1 1]
# yt : [INFO     ] 2022-02-16 09:43:14,006 Parameters: domain_left_edge          = [-20. -20. -20.]
# yt : [INFO     ] 2022-02-16 09:43:14,007 Parameters: domain_right_edge         = [20. 20. 20.]
# yt : [INFO     ] 2022-02-16 09:43:14,007 Parameters: cosmological_simulation   = 0
# yt : [INFO     ] 2022-02-16 09:43:14,018 Omega Lambda is 0.0, so we are turning off Cosmology.
# yt : [INFO     ] 2022-02-16 09:43:14,072 Parameters: current_time              = 0.1
# yt : [INFO     ] 2022-02-16 09:43:14,073 Parameters: domain_dimensions         = [1 1 1]
# yt : [INFO     ] 2022-02-16 09:43:14,073 Parameters: domain_left_edge          = [-20. -20. -20.]
# yt : [INFO     ] 2022-02-16 09:43:14,074 Parameters: domain_right_edge         = [20. 20. 20.]
# yt : [INFO     ] 2022-02-16 09:43:14,075 Parameters: cosmological_simulation   = 0
# yt : [INFO     ] 2022-02-16 09:43:14,088 Omega Lambda is 0.0, so we are turning off Cosmology.
# yt : [INFO     ] 2022-02-16 09:43:14,142 Parameters: current_time              = 0.15000000000000002
# yt : [INFO     ] 2022-02-16 09:43:14,143 Parameters: domain_dimensions         = [1 1 1]
# yt : [INFO     ] 2022-02-16 09:43:14,143 Parameters: domain_left_edge          = [-20. -20. -20.]
# yt : [INFO     ] 2022-02-16 09:43:14,144 Parameters: domain_right_edge         = [20. 20. 20.]
# yt : [INFO     ] 2022-02-16 09:43:14,145 Parameters: cosmological_simulation   = 0
# yt : [INFO     ] 2022-02-16 09:43:14,155 Omega Lambda is 0.0, so we are turning off Cosmology.
# yt : [INFO     ] 2022-02-16 09:43:14,209 Parameters: current_time              = 0.2
# yt : [INFO     ] 2022-02-16 09:43:14,209 Parameters: domain_dimensions         = [1 1 1]
# snapshot_0001
# snapshot_0002
# snapshot_0003
# yt : [INFO     ] 2022-02-16 09:43:14,210 Parameters: domain_left_edge          = [-20. -20. -20.]
# yt : [INFO     ] 2022-02-16 09:43:14,211 Parameters: domain_right_edge         = [20. 20. 20.]
# yt : [INFO     ] 2022-02-16 09:43:14,211 Parameters: cosmological_simulation   = 0
# yt : [INFO     ] 2022-02-16 09:43:14,223 Omega Lambda is 0.0, so we are turning off Cosmology.
# yt : [INFO     ] 2022-02-16 09:43:14,278 Parameters: current_time              = 0.2
# yt : [INFO     ] 2022-02-16 09:43:14,279 Parameters: domain_dimensions         = [1 1 1]
# yt : [INFO     ] 2022-02-16 09:43:14,279 Parameters: domain_left_edge          = [-20. -20. -20.]
# yt : [INFO     ] 2022-02-16 09:43:14,280 Parameters: domain_right_edge         = [20. 20. 20.]
# yt : [INFO     ] 2022-02-16 09:43:14,281 Parameters: cosmological_simulation   = 0
# yt : [INFO     ] 2022-02-16 09:43:14,303 Omega Lambda is 0.0, so we are turning off Cosmology.
# yt : [INFO     ] 2022-02-16 09:43:14,356 Parameters: current_time              = 0.0
# yt : [INFO     ] 2022-02-16 09:43:14,356 Parameters: domain_dimensions         = [1 1 1]
# yt : [INFO     ] 2022-02-16 09:43:14,357 Parameters: domain_left_edge          = [-20. -20. -20.]
# yt : [INFO     ] 2022-02-16 09:43:14,358 Parameters: domain_right_edge         = [20. 20. 20.]
# yt : [INFO     ] 2022-02-16 09:43:14,358 Parameters: cosmological_simulation   = 0
# yt : [INFO     ] 2022-02-16 09:43:14,369 Omega Lambda is 0.0, so we are turning off Cosmology.
# snapshot_0004
# snapshot_0005
# snapshot_0000
# yt : [INFO     ] 2022-02-16 09:43:14,428 Parameters: current_time              = 0.05
# yt : [INFO     ] 2022-02-16 09:43:14,428 Parameters: domain_dimensions         = [1 1 1]
# yt : [INFO     ] 2022-02-16 09:43:14,429 Parameters: domain_left_edge          = [-20. -20. -20.]
# yt : [INFO     ] 2022-02-16 09:43:14,430 Parameters: domain_right_edge         = [20. 20. 20.]
# yt : [INFO     ] 2022-02-16 09:43:14,431 Parameters: cosmological_simulation   = 0
# yt : [INFO     ] 2022-02-16 09:43:14,444 Omega Lambda is 0.0, so we are turning off Cosmology.
# yt : [INFO     ] 2022-02-16 09:43:14,497 Parameters: current_time              = 0.1
# yt : [INFO     ] 2022-02-16 09:43:14,497 Parameters: domain_dimensions         = [1 1 1]
# yt : [INFO     ] 2022-02-16 09:43:14,498 Parameters: domain_left_edge          = [-20. -20. -20.]
# yt : [INFO     ] 2022-02-16 09:43:14,499 Parameters: domain_right_edge         = [20. 20. 20.]
# yt : [INFO     ] 2022-02-16 09:43:14,499 Parameters: cosmological_simulation   = 0
# yt : [INFO     ] 2022-02-16 09:43:14,512 Omega Lambda is 0.0, so we are turning off Cosmology.
# yt : [INFO     ] 2022-02-16 09:43:14,564 Parameters: current_time              = 0.15000000000000002
# yt : [INFO     ] 2022-02-16 09:43:14,565 Parameters: domain_dimensions         = [1 1 1]
# yt : [INFO     ] 2022-02-16 09:43:14,565 Parameters: domain_left_edge          = [-20. -20. -20.]
# yt : [INFO     ] 2022-02-16 09:43:14,566 Parameters: domain_right_edge         = [20. 20. 20.]
# yt : [INFO     ] 2022-02-16 09:43:14,567 Parameters: cosmological_simulation   = 0
# yt : [INFO     ] 2022-02-16 09:43:14,577 Omega Lambda is 0.0, so we are turning off Cosmology.
# yt : [INFO     ] 2022-02-16 09:43:14,628 Parameters: current_time              = 0.2
# yt : [INFO     ] 2022-02-16 09:43:14,629 Parameters: domain_dimensions         = [1 1 1]
# yt : [INFO     ] 2022-02-16 09:43:14,629 Parameters: domain_left_edge          = [-20. -20. -20.]
# yt : [INFO     ] 2022-02-16 09:43:14,630 Parameters: domain_right_edge         = [20. 20. 20.]
# yt : [INFO     ] 2022-02-16 09:43:14,630 Parameters: cosmological_simulation   = 0
# snapshot_0001
# snapshot_0002
# snapshot_0003
# snapshot_0004
# yt : [INFO     ] 2022-02-16 09:43:14,641 Omega Lambda is 0.0, so we are turning off Cosmology.
# yt : [INFO     ] 2022-02-16 09:43:14,694 Parameters: current_time              = 0.2
# yt : [INFO     ] 2022-02-16 09:43:14,694 Parameters: domain_dimensions         = [1 1 1]
# yt : [INFO     ] 2022-02-16 09:43:14,695 Parameters: domain_left_edge          = [-20. -20. -20.]
# yt : [INFO     ] 2022-02-16 09:43:14,696 Parameters: domain_right_edge         = [20. 20. 20.]
# yt : [INFO     ] 2022-02-16 09:43:14,696 Parameters: cosmological_simulation   = 0
# snapshot_0005

# %%
len(ds_Gall)
# Out:
# 24

# %% [markdown]
# # Extracting the data --

# %%
Idx=0
ds_Gall[Idx].length_unit.to('cm')
# Out:
# unyt_quantity(3.08568e+19, 'cm')

# %%
from os import listdir
listdir(sim_dir2)
# Out:
# ['snapshot_0001',
#  'snapshot_0000',
#  'snapshot_0005',
#  'snapshot_0002',
#  'snapshot_0003',
#  'snapshot_0004',
#  'parameters-usedvalues']

# %%
ds_Gall
# Out:
# [GadgetDataset: all_aciis_0/snapshot_0000,
#  GadgetDataset: all_aciis_0/snapshot_0001,
#  GadgetDataset: all_aciis_0/snapshot_0002,
#  GadgetDataset: all_aciis_0/snapshot_0003,
#  GadgetDataset: all_aciis_0/snapshot_0004,
#  GadgetDataset: all_aciis_0/snapshot_0005,
#  GadgetDataset: all_aciis_1/snapshot_0000,
#  GadgetDataset: all_aciis_1/snapshot_0001,
#  GadgetDataset: all_aciis_1/snapshot_0002,
#  GadgetDataset: all_aciis_1/snapshot_0003,
#  GadgetDataset: all_aciis_1/snapshot_0004,
#  GadgetDataset: all_aciis_1/snapshot_0005,
#  GadgetDataset: all_aciis_2/snapshot_0000,
#  GadgetDataset: all_aciis_2/snapshot_0001,
#  GadgetDataset: all_aciis_2/snapshot_0002,
#  GadgetDataset: all_aciis_2/snapshot_0003,
#  GadgetDataset: all_aciis_2/snapshot_0004,
#  GadgetDataset: all_aciis_2/snapshot_0005,
#  GadgetDataset: all_aciis_3/snapshot_0000,
#  GadgetDataset: all_aciis_3/snapshot_0001,
#  GadgetDataset: all_aciis_3/snapshot_0002,
#  GadgetDataset: all_aciis_3/snapshot_0003,
#  GadgetDataset: all_aciis_3/snapshot_0004,
#  GadgetDataset: all_aciis_3/snapshot_0005]

# %%
rhos=[]
vels=[]
rs=[]
## ---------------------------------------------------------
for Idx,k in enumerate(ds_Gall):
    rhos1 = ds_Gall[Idx].r["Gas", "Density"]
    rs1 = ds_Gall[Idx].r["all", "radius"]/Rad0
    print(Idx)
    if Idx == 0:
        vs1 = ds_Gall[Idx].r["all", "radial_velocity"]/Vel00
    else:
        vs1 = ds_Gall[Idx].r["all", "radial_velocity"]/Vel0
        
    rhos.append(rhos1)
    vels.append(vs1)
    rs.append(rs1)
# Out:
# yt : [INFO     ] 2022-02-16 09:43:21,327 Allocating for 2.332e+04 particles
# 0
# 1
# 2
# 3
# 4
# yt : [INFO     ] 2022-02-16 09:43:40,111 Allocating for 3.703e+04 particles
# 5
# 6
# 7
# 8
# 9
# 10
# yt : [INFO     ] 2022-02-16 09:43:57,029 Allocating for 6.401e+04 particles
# 11
# 12
# 13
# 14
# 15
# 16
# yt : [INFO     ] 2022-02-16 09:44:14,227 Allocating for 1.250e+05 particles
# 17
# 18
# 19
# 20
# 21
# 22
# 23

# %%
rs
# Out:
# [unyt_array([3.22975629, 3.09326487, 3.19822444, ..., 3.0634352 ,
#              2.92944792, 3.11687473], 'cm'),
#  unyt_array([3.22804112, 3.09139628, 3.19647568, ..., 3.06153034,
#              2.898824  , 3.11503411], 'cm'),
#  unyt_array([3.22392666, 3.08691139, 3.19227974, ..., 3.05695781,
#              2.86907384, 3.11061678], 'cm'),
#  unyt_array([3.21740645, 3.07980249, 3.18563021, ..., 3.04970972,
#              2.86473556, 3.10361529], 'cm'),
#  unyt_array([3.20847091, 3.0700576 , 3.17651697, ..., 3.03977324,
#              2.86281674, 3.09401815], 'cm'),
#  unyt_array([3.20847091, 3.0700576 , 3.17651697, ..., 3.03977324,
#              2.86281674, 3.09401815], 'cm'),
#  unyt_array([3.203909  , 3.1446461 , 3.20982173, ..., 3.07128455,
#              3.09958919, 3.11935859], 'cm'),
#  unyt_array([3.20216636, 3.14283762, 3.20808536, ..., 3.06938931,
#              3.09772814, 3.11752097], 'cm'),
#  unyt_array([3.19798527, 3.13849773, 3.20391967, ..., 3.06484012,
#              3.09326148, 3.11311063], 'cm'),
#  unyt_array([3.19135944, 3.13161959, 3.19731823, ..., 3.05762908,
#              3.0861817 , 3.10612033], 'cm'),
#  unyt_array([3.18227858, 3.1882709 , 3.19512316, ..., 3.04480432,
#              3.01307593, 3.07647667], 'cm'),
#  unyt_array([3.18227858, 3.1882709 , 3.19512316, ..., 3.04480432,
#              3.01307593, 3.07647667], 'cm'),
#  unyt_array([3.19745956, 3.22853901, 3.12271437, ..., 3.11990967,
#              3.23432274, 3.22652431], 'cm'),
#  unyt_array([3.22682255, 3.12088066, 3.19379316, ..., 3.11807264,
#              3.23261243, 3.22480575], 'cm'),
#  unyt_array([3.22270494, 3.11647974, 3.18959023, ..., 3.11366381,
#              3.22850945, 3.220683  ], 'cm'),
#  unyt_array([3.21617983, 3.10950441, 3.18292965, ..., 3.10667603,
#              3.22200783, 3.21414976], 'cm'),
#  unyt_array([3.25970449, 3.2072375 , 3.09994322, ..., 3.09709755,
#              3.2130976 , 3.20519632], 'cm'),
#  unyt_array([3.25970449, 3.2072375 , 3.09994322, ..., 3.09709755,
#              3.2130976 , 3.20519632], 'cm'),
#  unyt_array([3.24079201, 3.24899783, 3.25841348, ..., 3.24910325,
#              3.23152014, 3.2280176 ], 'cm'),
#  unyt_array([3.2390885 , 3.24730281, 3.25672814, ..., 3.24740845,
#              3.22980686, 3.22630062], 'cm'),
#  unyt_array([3.24323683, 3.26312344, 3.25268563, ..., 3.22569675,
#              3.24334251, 3.22218169], 'cm'),
#  unyt_array([3.22852598, 3.23679364, 3.2596521 , ..., 3.23689978,
#              3.21565444, 3.26106805], 'cm'),
#  unyt_array([3.25382755, 3.23750112, 3.15948441, ..., 3.21025804,
#              3.2280708 , 3.25782459], 'cm'),
#  unyt_array([3.25382755, 3.23750112, 3.15948441, ..., 3.21025804,
#              3.2280708 , 3.25782459], 'cm')]

# %% [markdown]
# # Bondi numerically in Python

# %%
from IPython.display import display, Math, Latex
import numpy as np
np.seterr(divide='ignore', invalid='ignore')

# %matplotlib inline
import matplotlib
import matplotlib.pyplot as plt

# %%
def plotBondiVelIndi(n,rb,velb,lbs,i):
    ## --- Estilo --
    putStyle(14,2,True,True)
    ## -------------
    ## ---
    plt.scatter(rb, velb, 2, 
                label=str(lbs)+' $\gamma$= '+str(n)+' t~'+str(i))
    ## ----------------------------------------------------
    plt.legend(loc='best')
    plt.xlabel(r'$r~(u.c)$')
    ## Limits--
    plt.xscale("log")
    plt.xlim(0.0005,5.1)
    plt.ylabel(r'$v_r~(u.c)$')
    plt.ylim(-40,5)

# %% [markdown]
# # n -> infty ... Isothermal $\gamma$ = 1

# %% [markdown]
# ## Creo arreglo de rhos y vels

# %%
rbArr=[]
VelbArr=[]
## ---- Rhos ----------------------------------------------------------------
RhobArr=[]
## -- version rapida:
nro1=[133000,133000,133000,133000,133000,133000,
      334000,334000,334000,334000,334000,334000,
      990900,990900,990900,990900,990900,990900,
      3500000,3500000,3500000,3500000,3500000,3500000,
      3500000,3500000,3500000,3500000,3500000,3500000]
#--
for i,(j,k,l) in enumerate(zip(rs,vels,rhos)):
    print(i, nro1[i], len(j.value))
#--
    idx1 = np.random.choice(np.arange(len(j.value)), len(j.value)-1, replace=False)
    rb, velb, rhob = j.value[idx1], k.value[idx1], l.value[idx1]
    rbArr.append(rb)
    VelbArr.append(velb)
    RhobArr.append(rhob)
# Out:
# 0 133000 23322
# 1 133000 23322
# 2 133000 23322
# 3 133000 23322
# 4 133000 23322
# 5 133000 23322
# 6 334000 37031
# 7 334000 37031
# 8 334000 37031
# 9 334000 37031
# 10 334000 37031
# 11 334000 37031
# 12 990900 64012
# 13 990900 64012
# 14 990900 64012
# 15 990900 64012
# 16 990900 64012
# 17 990900 64012
# 18 3500000 124987
# 19 3500000 124987
# 20 3500000 124987
# 21 3500000 124987
# 22 3500000 124987
# 23 3500000 124987

# %%
print("Time unit: ", ds_Gall[0].time_unit.in_units("kyr"))

# %%
ds_Gall

# %%
for i,ds1 in enumerate(ds_Gall):
    print(i, ds1)

# %% [markdown]
# # Gamma = 1

# %% [markdown]
# # CS64

# %%
n=1
# CS64
model1='CS64;'
nMod='1_1'
Idx1=0; Idx2=1; Idx3=2; Idx4=3;  
Idx5=4; Idx6=5; Idx7=6;

## -- Tiempo del ultimo --
myUnit1='kyr'
LastTime1=ds_Gall[Idx1].time_unit.in_units(myUnit1)
LastTime1=round(LastTime1.item(0))*0.0
## --
LastTime2=ds_Gall[Idx2].time_unit.in_units(myUnit1)
LastTime2=round(LastTime2.item(0))*0.05
## --
LastTime3=ds_Gall[Idx3].time_unit.in_units(myUnit1)
LastTime3=round(LastTime3.item(0))*0.1
## --
LastTime4=ds_Gall[Idx4].time_unit.in_units(myUnit1)
LastTime4=round(LastTime4.item(0))*0.15
## --
LastTime5=ds_Gall[Idx5].time_unit.in_units(myUnit1)
LastTime5=round(LastTime5.item(0))*0.2
## --

## ----- Las imagenes --
img1=plotBondiVelIndi(n,rbArr[Idx1],VelbArr[Idx1],model1,str(LastTime1)+' '+myUnit1)
img2=plotBondiVelIndi(n,rbArr[Idx2],VelbArr[Idx2],model1,str(LastTime2)+' '+myUnit1)
img3=plotBondiVelIndi(n,rbArr[Idx3],VelbArr[Idx3],model1,str(LastTime3)+' '+myUnit1)
img4=plotBondiVelIndi(n,rbArr[Idx4],VelbArr[Idx4],model1,str(LastTime4)+' '+myUnit1)
img5=plotBondiVelIndi(n,rbArr[Idx5],VelbArr[Idx5],model1,str(LastTime5)+' '+myUnit1)

# %% [markdown]
# # Cortes transversales ---

# %%
# ?annotate_timestamp
# Out:
# Object `annotate_timestamp` not found.

# %%
print("Time unit: ", ds_Gall[1].time_unit.in_units("kyr"))
# Out:
# Time unit:  149.0892633095566 kyr

# %%
ds_Gall[4]
# Out:
# GadgetDataset: all_aciis_0/snapshot_0004

# %%
Idx = 4
myUnit1='kyr'
LastTime1=ds_Gall[Idx].time_unit.in_units(myUnit1)
LastTime1=round(LastTime1.item(0))*0.2
model1='CS64-1'


ad = ds_Gall[Idx].all_data()
### Aqui defino --
density = ad[("Gas","Density")]
internal= ad[("Gas","InternalEnergy")]

#####
wdens = np.where(density == np.max(density))
coordinates = ad[("Gas","Coordinates")]
center = coordinates[wdens][0]
print('center = ',center)

### Nueva caja
new_box_size = ds_Gall[Idx].quan(2.5,'code_length')
left_edge = center - new_box_size/2
right_edge = center + new_box_size/2

print('Este es el box: ', new_box_size.in_units('pc'))
print(left_edge.in_units('pc'))
print(right_edge.in_units('pc'))

#####
px = yt.SlicePlot(ds_Gall[Idx], 'z', ('gas', 'density'), 
#center=[0.,new_box_size/2,new_box_size/2], width=new_box_size,
#origin='lower-left-window')
center=[0,0,0], width=new_box_size,
origin='center-window') #'lower-left-window'
px.set_unit('x','code_length')
px.set_unit('y','code_length')
px.set_unit(("gas", "density"),'code_density')
px.set_cmap(field="density", cmap='jet') ## amfhot,jet



px.annotate_text((-.5,.5), "(a) "+model1+'; t= '+str(LastTime1)+' '+myUnit1, 
                 coord_system="plot",
                 text_args={"color": "white", "size":26,
                           'family': 'sans-serif', 
                           'style': 'italic'})
# Out:
# yt : [INFO     ] 2022-02-16 10:07:02,860 xlim = -1.250000 1.250000
# yt : [INFO     ] 2022-02-16 10:07:02,860 ylim = -1.250000 1.250000
# yt : [INFO     ] 2022-02-16 10:07:02,861 xlim = -1.250000 1.250000
# yt : [INFO     ] 2022-02-16 10:07:02,862 ylim = -1.250000 1.250000
# yt : [INFO     ] 2022-02-16 10:07:02,863 Making a fixed resolution buffer of (('gas', 'density')) 800 by 800
# center =  [-1.66451871 -1.67051518  1.62310696] code_length
# Este es el box:  25.000019598918 pc
# [-29.14520999 -29.20517469   3.73107249] pc
# [-4.14519039 -4.20515509 28.73109209] pc
# /Users/josem/Desktop/Peiskos2020/CursoVAE101_v1/VAEtf1env/lib/python3.8/site-packages/yt/data_objects/data_containers.py:1421: VisibleDeprecationWarning: The requested field name 'x' is ambiguous and corresponds to any one of the following field types:
#  {'all', 'gas', 'Gas'}
# Please specify the requested field as an explicit tuple (ftype, fname).
# Defaulting to '("gas", "x")'.
# Deprecated since v4.0.0. This feature will be removed in v4.1.0
#   finfo = self.ds._get_field_info(field)
# yt : [INFO     ] 2022-02-16 10:07:04,258 Making a fixed resolution buffer of (('gas', 'x')) 800 by 800
# /Users/josem/Desktop/Peiskos2020/CursoVAE101_v1/VAEtf1env/lib/python3.8/site-packages/yt/data_objects/data_containers.py:1421: VisibleDeprecationWarning: The requested field name 'y' is ambiguous and corresponds to any one of the following field types:
#  {'all', 'gas', 'Gas'}
# Please specify the requested field as an explicit tuple (ftype, fname).
# Defaulting to '("gas", "y")'.
# Deprecated since v4.0.0. This feature will be removed in v4.1.0
#   finfo = self.ds._get_field_info(field)
# yt : [INFO     ] 2022-02-16 10:07:05,075 Making a fixed resolution buffer of (('gas', 'y')) 800 by 800
# /Users/josem/Desktop/Peiskos2020/CursoVAE101_v1/VAEtf1env/lib/python3.8/site-packages/yt/data_objects/data_containers.py:1421: VisibleDeprecationWarning: The requested field name 'density' is ambiguous and corresponds to any one of the following field types:
#  {'all', 'gas'}
# Please specify the requested field as an explicit tuple (ftype, fname).
# Defaulting to '("gas", "density")'.
# Deprecated since v4.0.0. This feature will be removed in v4.1.0
#   finfo = self.ds._get_field_info(field)
# <img style="max-width:100%;max-height:100%;" src="data:image/png;base64,..."><br>

# %%
px.save()
# Out:
# yt : [INFO     ] 2022-02-16 10:07:14,291 Saving plot snapshot_0004_Slice_z_density.png
# ['snapshot_0004_Slice_z_density.png']

# %% [markdown]
# # Solving and Plotting semi-Analytical solutions

# %%
TX=1.e7
pc = 3.18e+18
BOLTZMANN  = 1.3806e-16
PROTONMASS = 1.6726e-24
HYDROGEN_MASSFRAC = 0.625
mass_sun = 1.989e+33  ## g
RHO0 = 1.0e-19        ## Density at infty
Gnew = 6.672e-8       ##
myPI = 3.14159
Mbh  = 1.e+8*mass_sun ## Black hole mass
## --
#Rad0 = 3.08568025e+19 ## cm (10pc)
myGamma=1.

## 
Uvel = np.sqrt((myGamma * BOLTZMANN * TX)/(HYDROGEN_MASSFRAC*PROTONMASS))
Uvel
# Out:
# 36341084.17671472

# %%
Rb=Gnew* Mbh/(Uvel*Uvel) #3.*(Mbh/(1.e+8*mass_sun))/(TX/1.e+7)
FactX=Rb/(Rad0)
FactX
# Out:
# 0.3256448211948118

# %% [markdown]
# # Isothermal Model

# %%
with open('../Profiles_G1_v5.txt') as f:
    lines1 = f.readlines()

# %%
lines1[:10]
# Out:
# ['0.00500\t19.6094707874\t2285.4717085060\n',
#  '0.00600\t17.8439139149\t1744.1712011540\n',
#  '0.00700\t16.4694416177\t1388.3749731020\n',
#  '0.00800\t15.3597798998\t1139.7688017180\n',
#  '0.00900\t14.4392725456\t957.9688748291\n',
#  '0.01000\t13.6594572447\t820.2538706454\n',
#  '0.01100\t12.9876606813\t712.9604313727\n',
#  '0.01200\t12.4009437556\t627.4288751636\n',
#  '0.01300\t11.8826629917\t557.9319689774\n',
#  '0.01400\t11.4204090922\t500.5460044881\n']

# %%
Fact1=1.27 #
Fact2=0.001

xIso=[]
MIso=[]
RhoIso=[]
for line in lines1[5:]:
    xIso.append(FactX*np.float(line.split('\t')[0]))
    MIso.append(-Fact1*np.float(np.float(line.split('\t')[1])))
    RhoIso.append(Fact2 * np.float(np.float(line.split('\t')[2])))
#MIso

# %%
from scipy import interpolate

def plotBondiVelRatio(n,rb,velb,lbs,i):
    ## --- Estilo --
    #plt.figure(figsize=(8,2))
    putStyle(14,2,True,True)
    ## -------------
    # Interpolation
    temp = interpolate.interp1d(xIso, MIso)
    ## ---
    ynew = temp(rb[np.where((np.min(xIso) < rb) & (rb < np.max(xIso)))])
    xnew = rb[np.where((np.min(xIso) < rb) & (rb < np.max(xIso)))]
    
    
    plt.scatter(xnew, (velb[np.where((np.min(xIso) < rb) & (rb < np.max(xIso)))] - ynew), 2)
    #           2, label=str(lbs)+' $\gamma$= '+str(n)+' t~'+str(i))
    plt.axhline(y = 0., color = 'black', linestyle = '--')
    ## ----------------------------------------------------
    #plt.legend(loc='best')
    plt.xlabel(r'$r~(u.c)$')
    ## Limits--
    plt.xscale("log")
    plt.xlim(0.005, 5.1)
    plt.ylabel(r'Diff')
    plt.ylim(-5, 5)

# %% [markdown]
# # CS64 -1

# %%
# plt.xscale("log")
plt.figure(figsize=(8,3))

n=1
# CS64-1
model1='CS64-1'
nMod='Final_Fig1'
Idx1=0; Idx2=1; Idx3=2; Idx4=3;  
Idx5=4; Idx6=5; Idx7=6;

## -- Tiempo del ultimo --
myUnit1='kyr'
## --
LastTime2=ds_Gall[Idx2].time_unit.in_units(myUnit1)
LastTime2=round(LastTime2.item(0))*0.05
## --
LastTime3=ds_Gall[Idx3].time_unit.in_units(myUnit1)
LastTime3=round(LastTime3.item(0))*0.1
## --
LastTime4=ds_Gall[Idx4].time_unit.in_units(myUnit1)
LastTime4=round(LastTime4.item(0))*0.15
## --
LastTime5=ds_Gall[Idx5].time_unit.in_units(myUnit1)
LastTime5=round(LastTime5.item(0))*0.2
## --



## ----- Las imagenes --
img2=plotBondiVelRatio(n,rbArr[Idx2]*FactX,VelbArr[Idx2]/Fact1,model1,str(LastTime2)+' '+myUnit1)
img3=plotBondiVelRatio(n,rbArr[Idx3]*FactX,VelbArr[Idx3]/Fact1,model1,str(LastTime3)+' '+myUnit1)
img4=plotBondiVelRatio(n,rbArr[Idx4]*FactX,VelbArr[Idx4]/Fact1,model1,'1.35'+' '+myUnit1)
img5=plotBondiVelRatio(n,rbArr[Idx5]*FactX,VelbArr[Idx5]/Fact1,model1,str(LastTime5)+' '+myUnit1)


plt.savefig(str(model1)+'_'+str(nMod)+'_Vel_Diff_v1.png')

# %%
plt.xscale("log")
#plt.figure(figsize=(8,6))

n=1
plt.plot(xIso,MIso,'black', 
         label='$\gamma$= '+str(n)+'; Theoretical - Ramirez etal. 2021')


# CS64-1
model1='CS64-1'
nMod='Final_Fig1'
Idx1=0; Idx2=1; Idx3=2; Idx4=3;  
Idx5=4; Idx6=5; Idx7=6;

## -- Tiempo del ultimo --
myUnit1='kyr'
## --
LastTime2=ds_Gall[Idx2].time_unit.in_units(myUnit1)
LastTime2=round(LastTime2.item(0))*0.05
## --
LastTime3=ds_Gall[Idx3].time_unit.in_units(myUnit1)
LastTime3=round(LastTime3.item(0))*0.1
## --
LastTime4=ds_Gall[Idx4].time_unit.in_units(myUnit1)
LastTime4=round(LastTime4.item(0)*0.15)
## --
LastTime5=ds_Gall[Idx5].time_unit.in_units(myUnit1)
LastTime5=round(LastTime5.item(0))*0.2
## --



## ----- Las imagenes --
img2=plotBondiVelIndi(n,rbArr[Idx2]*FactX,VelbArr[Idx2]/Fact1,model1,str(LastTime2)+' '+myUnit1)
img3=plotBondiVelIndi(n,rbArr[Idx3]*FactX,VelbArr[Idx3]/Fact1,model1,str(LastTime3)+' '+myUnit1)
img4=plotBondiVelIndi(n,rbArr[Idx4]*FactX,VelbArr[Idx4]/Fact1,model1,str(LastTime4)+' '+myUnit1)
img5=plotBondiVelIndi(n,rbArr[Idx5]*FactX,VelbArr[Idx5]/Fact1,model1,str(LastTime5)+' '+myUnit1)


plt.savefig(str(model1)+'_'+str(nMod)+'_Vel_v1.png')

# %% [markdown]
# # CS64-2

# %%
# plt.xscale("log")
plt.figure(figsize=(8,3))

n=1
#plt.plot(xIso,MIso,'blue', 
#         label='$\gamma$= '+str(n)+'; Theoretical - Ramirez etal. 2021')


# W256
model1='CS64-2'
nMod='Final_Fig1'
Idx1=6; Idx2=7; Idx3=8; Idx4=9;  
Idx5=10; Idx6=11;

## -- Tiempo del ultimo --
myUnit1='kyr'
LastTime1=ds_Gall[Idx1].time_unit.in_units(myUnit1)
LastTime1=round(LastTime1.item(0))*0.0
## --
LastTime2=ds_Gall[Idx2].time_unit.in_units(myUnit1)
LastTime2=round(LastTime2.item(0))*0.05
## --
LastTime3=ds_Gall[Idx3].time_unit.in_units(myUnit1)
LastTime3=round(LastTime3.item(0))*0.1
## --
LastTime4=ds_Gall[Idx4].time_unit.in_units(myUnit1)
LastTime4=round(LastTime4.item(0))*0.15
## --
LastTime5=ds_Gall[Idx5].time_unit.in_units(myUnit1)
LastTime5=round(LastTime5.item(0))*0.2
## --



## ----- Las imagenes --
img2=plotBondiVelRatio(n,rbArr[Idx2]*FactX,VelbArr[Idx2]/Fact1,model1,str(LastTime2)+' '+myUnit1)
img3=plotBondiVelRatio(n,rbArr[Idx3]*FactX,VelbArr[Idx3]/Fact1,model1,str(LastTime3)+' '+myUnit1)
img4=plotBondiVelRatio(n,rbArr[Idx4]*FactX,VelbArr[Idx4]/Fact1,model1,'22.4'+' '+myUnit1)
img5=plotBondiVelRatio(n,rbArr[Idx5]*FactX,VelbArr[Idx5]/Fact1,model1,str(LastTime5)+' '+myUnit1)


plt.savefig(str(model1)+'_'+str(nMod)+'_Vel_Diff_v1.png')

# %%
plt.xscale("log")
#plt.figure(figsize=(8,6))

n=1
plt.plot(xIso,MIso,'black', 
         label='$\gamma$= '+str(n)+'; Theoretical - Ramirez etal. 2021')


# W256
model1='CS64-2'
nMod='Final_Fig1'
Idx1=6; Idx2=7; Idx3=8; Idx4=9;  
Idx5=10; Idx6=11;

## -- Tiempo del ultimo --
myUnit1='kyr'
## --
LastTime2=ds_Gall[Idx2].time_unit.in_units(myUnit1)
LastTime2=round(LastTime2.item(0))*0.05
## --
LastTime3=ds_Gall[Idx3].time_unit.in_units(myUnit1)
LastTime3=round(LastTime3.item(0))*0.1
## --
LastTime4=ds_Gall[Idx4].time_unit.in_units(myUnit1)
LastTime4=round(LastTime4.item(0)*0.15)
## --
LastTime5=ds_Gall[Idx5].time_unit.in_units(myUnit1)
LastTime5=round(LastTime5.item(0))*0.2
## --



## ----- Las imagenes --
img2=plotBondiVelIndi(n,rbArr[Idx2]*FactX,VelbArr[Idx2]/Fact1,model1,str(LastTime2)+' '+myUnit1)
img3=plotBondiVelIndi(n,rbArr[Idx3]*FactX,VelbArr[Idx3]/Fact1,model1,str(LastTime3)+' '+myUnit1)
img4=plotBondiVelIndi(n,rbArr[Idx4]*FactX,VelbArr[Idx4]/Fact1,model1,str(LastTime4)+' '+myUnit1)
img5=plotBondiVelIndi(n,rbArr[Idx5]*FactX,VelbArr[Idx5]/Fact1,model1,str(LastTime5)+' '+myUnit1)


plt.savefig(str(model1)+'_'+str(nMod)+'_Vel_v1.png')

# %% [markdown]
# # CS64-3

# %%
# plt.xscale("log")
plt.figure(figsize=(8,3))

n=1
#plt.plot(xIso,MIso,'blue', 
#         label='$\gamma$= '+str(n)+'; Theoretical - Ramirez etal. 2021')


# W256
model1='CS64-3'
nMod='Final_Fig1'
Idx1=12; Idx2=13; Idx3=14; Idx4=15;  
Idx5=16; Idx6=17;

## -- Tiempo del ultimo --
myUnit1='kyr'
LastTime1=ds_Gall[Idx1].time_unit.in_units(myUnit1)
LastTime1=round(LastTime1.item(0))*0.0
## --
LastTime2=ds_Gall[Idx2].time_unit.in_units(myUnit1)
LastTime2=round(LastTime2.item(0))*0.05
## --
LastTime3=ds_Gall[Idx3].time_unit.in_units(myUnit1)
LastTime3=round(LastTime3.item(0))*0.1
## --
LastTime4=ds_Gall[Idx4].time_unit.in_units(myUnit1)
LastTime4=round(LastTime4.item(0)*0.15)
## --
LastTime5=ds_Gall[Idx5].time_unit.in_units(myUnit1)
LastTime5=round(LastTime5.item(0))*0.2
## --



## ----- Las imagenes --
img2=plotBondiVelRatio(n,rbArr[Idx2]*FactX,VelbArr[Idx2]/Fact1,model1,str(LastTime2)+' '+myUnit1)
img3=plotBondiVelRatio(n,rbArr[Idx3]*FactX,VelbArr[Idx3]/Fact1,model1,str(LastTime3)+' '+myUnit1)
img4=plotBondiVelRatio(n,rbArr[Idx4]*FactX,VelbArr[Idx4]/Fact1,model1,'22.4'+' '+myUnit1)
img5=plotBondiVelRatio(n,rbArr[Idx5]*FactX,VelbArr[Idx5]/Fact1,model1,str(LastTime5)+' '+myUnit1)


plt.savefig(str(model1)+'_'+str(nMod)+'_Vel_Diff_v1.png')

# %%
plt.xscale("log")
#plt.figure(figsize=(8,6))

n=1
plt.plot(xIso,MIso,'black', 
         label='$\gamma$= '+str(n)+'; Theoretical - Ramirez etal. 2021')


# W256
model1='CS64-3'
nMod='Final_Fig1'
Idx1=12; Idx2=13; Idx3=14; Idx4=15;  
Idx5=16; Idx6=17;

## -- Tiempo del ultimo --
myUnit1='kyr'
LastTime1=ds_Gall[Idx1].time_unit.in_units(myUnit1)
LastTime1=round(LastTime1.item(0))*0.0
## --
LastTime2=ds_Gall[Idx2].time_unit.in_units(myUnit1)
LastTime2=round(LastTime2.item(0))*0.05
## --
LastTime3=ds_Gall[Idx3].time_unit.in_units(myUnit1)
LastTime3=round(LastTime3.item(0))*0.1
## --
LastTime4=ds_Gall[Idx4].time_unit.in_units(myUnit1)
LastTime4=round(LastTime4.item(0)*0.15)
## --
LastTime5=ds_Gall[Idx5].time_unit.in_units(myUnit1)
LastTime5=round(LastTime5.item(0))*0.2
## --



## ----- Las imagenes --
img2=plotBondiVelIndi(n,rbArr[Idx2]*FactX,VelbArr[Idx2]/Fact1,model1,str(LastTime2)+' '+myUnit1)
img3=plotBondiVelIndi(n,rbArr[Idx3]*FactX,VelbArr[Idx3]/Fact1,model1,str(LastTime3)+' '+myUnit1)
img4=plotBondiVelIndi(n,rbArr[Idx4]*FactX,VelbArr[Idx4]/Fact1,model1,str(LastTime4)+' '+myUnit1)
img5=plotBondiVelIndi(n,rbArr[Idx5]*FactX,VelbArr[Idx5]/Fact1,model1,str(LastTime5)+' '+myUnit1)


plt.savefig(str(model1)+'_'+str(nMod)+'_Vel_v1.png')

# %% [markdown]
# # CS64-4

# %%
# plt.xscale("log")
plt.figure(figsize=(8,3))

n=1
#plt.plot(xIso,MIso,'blue', 
#         label='$\gamma$= '+str(n)+'; Theoretical - Ramirez etal. 2021')


# W256
model1='CS64-4'
nMod='Final_Fig1'
Idx1=18; Idx2=19; Idx3=20; Idx4=21;  
Idx5=22; Idx6=23;

## -- Tiempo del ultimo --
myUnit1='kyr'
LastTime1=ds_Gall[Idx1].time_unit.in_units(myUnit1)
LastTime1=round(LastTime1.item(0))*0.0
## --
LastTime2=ds_Gall[Idx2].time_unit.in_units(myUnit1)
LastTime2=round(LastTime2.item(0))*0.05
## --
LastTime3=ds_Gall[Idx3].time_unit.in_units(myUnit1)
LastTime3=round(LastTime3.item(0))*0.1
## --
LastTime4=ds_Gall[Idx4].time_unit.in_units(myUnit1)
LastTime4=round(LastTime4.item(0)*0.15)
## --
LastTime5=ds_Gall[Idx5].time_unit.in_units(myUnit1)
LastTime5=round(LastTime5.item(0))*0.2
## --



## ----- Las imagenes --
img2=plotBondiVelRatio(n,rbArr[Idx2]*FactX,VelbArr[Idx2]/Fact1,model1,str(LastTime2)+' '+myUnit1)
img3=plotBondiVelRatio(n,rbArr[Idx3]*FactX,VelbArr[Idx3]/Fact1,model1,str(LastTime3)+' '+myUnit1)
img4=plotBondiVelRatio(n,rbArr[Idx4]*FactX,VelbArr[Idx4]/Fact1,model1,'22.4'+' '+myUnit1)
img5=plotBondiVelRatio(n,rbArr[Idx5]*FactX,VelbArr[Idx5]/Fact1,model1,str(LastTime5)+' '+myUnit1)


plt.savefig(str(model1)+'_'+str(nMod)+'_Vel_Diff_v1.png')

# %%
plt.xscale("log")
#plt.figure(figsize=(8,6))

n=1
plt.plot(xIso,MIso,'black', 
         label='$\gamma$= '+str(n)+'; Theoretical - Ramirez etal. 2021')


# W256
model1='CS64-4'
nMod='Final_Fig1'
Idx1=18; Idx2=19; Idx3=20; Idx4=21;  
Idx5=22; Idx6=23;

## -- Tiempo del ultimo --
myUnit1='kyr'
LastTime1=ds_Gall[Idx1].time_unit.in_units(myUnit1)
LastTime1=round(LastTime1.item(0))*0.0
## --
LastTime2=ds_Gall[Idx2].time_unit.in_units(myUnit1)
LastTime2=round(LastTime2.item(0))*0.05
## --
LastTime3=ds_Gall[Idx3].time_unit.in_units(myUnit1)
LastTime3=round(LastTime3.item(0))*0.1
## --
LastTime4=ds_Gall[Idx4].time_unit.in_units(myUnit1)
LastTime4=round(LastTime4.item(0)*0.15)
## --
LastTime5=ds_Gall[Idx5].time_unit.in_units(myUnit1)
LastTime5=round(LastTime5.item(0))*0.2
## --



## ----- Las imagenes --
img2=plotBondiVelIndi(n,rbArr[Idx2]*FactX,VelbArr[Idx2]/Fact1,model1,str(LastTime2)+' '+myUnit1)
img3=plotBondiVelIndi(n,rbArr[Idx3]*FactX,VelbArr[Idx3]/Fact1,model1,str(LastTime3)+' '+myUnit1)
img4=plotBondiVelIndi(n,rbArr[Idx4]*FactX,VelbArr[Idx4]/Fact1,model1,str(LastTime4)+' '+myUnit1)
img5=plotBondiVelIndi(n,rbArr[Idx5]*FactX,VelbArr[Idx5]/Fact1,model1,str(LastTime5)+' '+myUnit1)


plt.savefig(str(model1)+'_'+str(nMod)+'_Vel_v1.png')
